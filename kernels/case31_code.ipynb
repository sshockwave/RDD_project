# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='case31'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return -0.2*((x-59)**2)-0.4*(x-59)+2

# %%
def get_data():
    n1=60
    n2=0.2
    m=18
    X=np.random.rand(n1)*10-5+59 #can change the distribution of X
    for j in range(1,m):
        B=59-0.2*j-np.random.rand(int(n2*(m-j)))*0.2*(m-j)
        X=np.hstack((X,B))
    Y=np.vectorize(actual_f)(X)
    for k in range(3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.60208981 0.68902535]
# Running param set  1 [0.6875408  0.00822762]
# Running param set  2 [0.95790469 0.32913884]
# Running param set  3 [0.43896667 0.44150405]
# Running param set  4 [0.51650589 0.66927452]
# Running param set  5 [0.79586512 0.97494857]
# Running param set  6 [0.12245571 0.59656296]
# Running param set  7 [0.14155645 0.12485993]
# Running param set  8 [0.5805685  0.89336619]
# Running param set  9 [0.310943  0.2044275]
# Running param set  10 [0.39610118 0.55199844]
# Running param set  11 [0.12262852 0.11682981]
# Running param set  12 [0.10236102 0.87082036]
# Running param set  13 [0.04415399 0.21019646]
# Running param set  14 [0.06814329 0.61320137]
# Running param set  15 [0.94625228 0.23547734]
# Running param set  16 [0.31797249 0.26203559]
# Running param set  17 [0.33680755 0.52925317]
# Running param set  18 [0.72157266 0.61166653]
# Running param set  19 [0.14499245 0.54561975]
# Running param set  20 [0.68222621 0.21717225]
# Running param set  21 [0.16369133 0.65062233]
# Running param set  22 [0.07089803 0.2347244 ]
# Running param set  23 [0.91911449 0.94277783]
# Running param set  24 [0.19997141 0.78334637]
# Running param set  25 [0.65466876 0.46009037]
# Running param set  26 [0.5016772  0.14084227]
# Running param set  27 [0.09951168 0.61656445]
# Running param set  28 [0.70653711 0.09232565]
# Running param set  29 [0.12444443 0.37881785]
# Running param set  30 [0.07193842 0.37766403]
# Running param set  31 [0.56228936 0.88110918]
# Running param set  32 [0.47190069 0.33055525]
# Running param set  33 [0.20997955 0.76930288]
# Running param set  34 [0.05989479 0.42608272]
# Running param set  35 [0.07883898 0.31576772]
# Running param set  36 [0.30531538 0.31277498]
# Running param set  37 [0.54932958 0.24319358]
# Running param set  38 [0.19044951 0.26686592]
# Running param set  39 [0.32619366 0.52386922]
# Running param set  40 [0.69266381 0.94949641]
# Running param set  41 [0.63165528 0.74098066]
# Running param set  42 [0.07808844 0.92340514]
# Running param set  43 [0.86323991 0.5874194 ]
# Running param set  44 [0.36809822 0.66683219]
# Running param set  45 [0.45453954 0.09150734]
# Running param set  46 [0.27610532 0.08529893]
# Running param set  47 [0.48148258 0.07714303]
# Running param set  48 [0.87657043 0.84827317]
# Running param set  49 [0.26907639 0.01824932]
# Running param set  50 [0.57957485 0.63104788]
# Running param set  51 [0.29655228 0.61148094]
# Running param set  52 [0.51843545 0.606087  ]
# Running param set  53 [0.24390686 0.73960794]
# Running param set  54 [0.45255782 0.25959697]
# Running param set  55 [0.26140685 0.32274574]
# Running param set  56 [0.49842004 0.00615973]
# Running param set  57 [0.05781448 0.77549756]
# Running param set  58 [0.5454788  0.08585616]
# Running param set  59 [0.82354871 0.43240939]
# Running param set  60 [0.62602366 0.26313747]
# Running param set  61 [0.91589712 0.43007987]
# Running param set  62 [0.91246339 0.20835712]
# Running param set  63 [0.61434187 0.72035298]
# Running param set  64 [0.18745814 0.51122569]
# Running param set  65 [0.81810311 0.6030258 ]
# Running param set  66 [0.42447782 0.99526254]
# Running param set  67 [0.18170067 0.97010152]
# Running param set  68 [0.27104344 0.42095778]
# Running param set  69 [0.70770444 0.60990444]
# Running param set  70 [0.5473499  0.32086224]
# Running param set  71 [0.93131185 0.71735622]
# Running param set  72 [0.68904179 0.10149184]
# Running param set  73 [0.19013144 0.57401505]
# Running param set  74 [0.50247415 0.57506888]
# Running param set  75 [0.82387574 0.41641465]
# Running param set  76 [0.43928025 0.12092265]
# Running param set  77 [0.7029308  0.27280652]
# Running param set  78 [0.05534934 0.29624066]
# Running param set  79 [0.60351731 0.94410286]
# Running param set  80 [0.94507698 0.17200746]
# Running param set  81 [0.55296585 0.78976423]
# Running param set  82 [0.41568384 0.64865803]
# Running param set  83 [0.0161014  0.02153692]
# Running param set  84 [0.0771939  0.63122193]
# Running param set  85 [0.6522751  0.44032909]
# Running param set  86 [0.22137577 0.3177177 ]
# Running param set  87 [0.90297731 0.10289073]
# Running param set  88 [0.9748525  0.39202701]
# Running param set  89 [0.23454615 0.87081788]
# Running param set  90 [0.69868904 0.18604404]
# Running param set  91 [0.40356083 0.31638435]
# Running param set  92 [0.18164801 0.78572138]
# Running param set  93 [0.73856459 0.75035982]
# Running param set  94 [0.51854519 0.05127839]
# Running param set  95 [0.83737755 0.42584166]
# Running param set  96 [0.15101138 0.43280228]
# Running param set  97 [0.72699055 0.93121829]
# Running param set  98 [0.56994186 0.39502723]
# Running param set  99 [0.36072687 0.26492597]
# Running param set  100 [0.06741181 0.91705515]
# Running param set  101 [0.52475871 0.7762716 ]
# Running param set  102 [0.01493783 0.08987069]
# Running param set  103 [0.76476341 0.71544541]
# Running param set  104 [0.71309759 0.86920079]
# Running param set  105 [0.39477938 0.10648275]
# Running param set  106 [0.13468876 0.07043923]
# Running param set  107 [0.06144585 0.53169478]
# Running param set  108 [0.45472069 0.00077445]
# Running param set  109 [0.64510045 0.89041648]
# Running param set  110 [0.32579178 0.07992241]
# Running param set  111 [0.23964193 0.33855538]
# Running param set  112 [0.18150735 0.5331244 ]
# Running param set  113 [0.00471447 0.68232361]
# Running param set  114 [0.55658847 0.30052   ]
# Running param set  115 [0.18838546 0.77380855]
# Running param set  116 [0.8955146 0.6897218]
# Running param set  117 [0.6767493  0.16927868]
# Running param set  118 [0.32392058 0.15831159]
# Running param set  119 [0.33994345 0.91150247]
# Running param set  120 [0.7470548  0.30642992]
# Running param set  121 [0.86809959 0.8142497 ]
# Running param set  122 [0.71679599 0.37156738]
# Running param set  123 [0.29636053 0.14730075]
# Running param set  124 [0.05400137 0.61023421]
# Running param set  125 [0.23370913 0.79921809]
# Running param set  126 [0.2524784  0.64193897]
# Running param set  127 [0.88501366 0.14138813]
# Running param set  128 [0.47370392 0.30598367]
# Running param set  129 [0.91970152 0.71840071]
# Running param set  130 [0.29764449 0.13448347]
# Running param set  131 [0.0871422  0.90674548]
# Running param set  132 [0.88627702 0.08221119]
# Running param set  133 [0.69601587 0.78156407]
# Running param set  134 [0.80655577 0.22697081]
# Running param set  135 [0.89176181 0.77078172]
# Running param set  136 [0.22076057 0.43413828]
# Running param set  137 [0.77521916 0.34199615]
# Running param set  138 [0.66884216 0.4429853 ]
# Running param set  139 [0.910599  0.7582328]
# Running param set  140 [0.23224353 0.48082306]
# Running param set  141 [0.84068134 0.21111894]
# Running param set  142 [0.9747814 0.5625149]
# Running param set  143 [0.6360508 0.0913156]
# Running param set  144 [0.63631471 0.08995017]
# Running param set  145 [0.94088307 0.43095812]
# Running param set  146 [0.04252169 0.12276068]
# Running param set  147 [0.92287511 0.27348582]
# Running param set  148 [0.87843885 0.337379  ]
# Running param set  149 [0.38286625 0.77605976]
# Running param set  150 [0.83396953 0.5143006 ]
# Running param set  151 [0.50420729 0.56157026]
# Running param set  152 [0.53899369 0.78524597]
# Running param set  153 [0.47390738 0.74824117]
# Running param set  154 [0.54946392 0.89583683]
# Running param set  155 [0.52045356 0.17619359]
# Running param set  156 [0.57721907 0.77117953]
# Running param set  157 [0.78764442 0.24911069]
# Running param set  158 [0.48237218 0.0799395 ]
# Running param set  159 [0.75829917 0.60195451]
# Running param set  160 [0.91711752 0.87367258]
# Running param set  161 [0.64665695 0.31674957]
# Running param set  162 [0.29592073 0.24975333]
# Running param set  163 [0.10220602 0.31505325]
# Running param set  164 [0.15861145 0.28681405]
# Running param set  165 [0.2788646  0.85504352]
# Running param set  166 [0.7594631  0.96135458]
# Running param set  167 [0.43334517 0.18159821]
# Running param set  168 [0.61032568 0.87202381]
# Running param set  169 [0.38956271 0.24173084]
# Running param set  170 [0.51280979 0.19151458]
# Running param set  171 [0.37189097 0.04786968]
# Running param set  172 [0.91091095 0.13453279]
# Running param set  173 [0.44551546 0.28196459]
# Running param set  174 [0.92618223 0.03697389]
# Running param set  175 [0.3691481  0.34408009]
# Running param set  176 [0.29646364 0.03117075]
# Running param set  177 [0.47642148 0.04387528]
# Running param set  178 [0.04026911 0.10112494]
# Running param set  179 [0.95378702 0.42713512]
# Running param set  180 [0.15783929 0.71258188]
# Running param set  181 [0.1783392  0.43165398]
# Running param set  182 [0.84979797 0.36518296]
# Running param set  183 [0.80285975 0.95044097]
# Running param set  184 [0.38204411 0.22706867]
# Running param set  185 [0.20653394 0.71548058]
# Running param set  186 [0.2796221  0.75295762]
# Running param set  187 [0.86715261 0.4618008 ]
# Running param set  188 [0.61327431 0.15810865]
# Running param set  189 [0.17216477 0.1392418 ]
# Running param set  190 [0.49623941 0.38126271]
# Running param set  191 [0.9933332  0.15703439]
# Running param set  192 [0.71748122 0.41421074]
# Running param set  193 [0.14333505 0.9192183 ]
# Running param set  194 [0.86450689 0.36362065]
# Running param set  195 [0.82306321 0.4967672 ]
# Running param set  196 [0.17345781 0.31714105]
# Running param set  197 [0.14425991 0.13167997]
# Running param set  198 [0.44802877 0.15132207]
# Running param set  199 [0.42981499 0.59039255]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
