# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='case20'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return 0.2*((x-59)**2)+2

# %%
def get_data():
    n1=60
    n2=0.2
    m=36
    X=np.random.rand(n1)*10-5+59 #can change the distribution of X
    for j in range(1,m):
        B=59-np.random.rand(int(n2*(m-j)))*0.1*(m-j)
        X=np.hstack((X,B))
    Y=np.vectorize(actual_f)(X)
    for k in range(3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.65179597 0.41596077]
# Running param set  1 [0.85175058 0.1260492 ]
# Running param set  2 [0.21753083 0.14041494]
# Running param set  3 [0.52266796 0.28678279]
# Running param set  4 [0.44454006 0.97646271]
# Running param set  5 [0.10656012 0.94163442]
# Running param set  6 [0.77146075 0.82714794]
# Running param set  7 [0.84717171 0.0748166 ]
# Running param set  8 [0.87526389 0.77438746]
# Running param set  9 [0.20917349 0.06054442]
# Running param set  10 [0.47681851 0.44525745]
# Running param set  11 [0.02178773 0.6053649 ]
# Running param set  12 [0.97339    0.98424925]
# Running param set  13 [0.51963076 0.71130729]
# Running param set  14 [0.43874813 0.91710667]
# Running param set  15 [0.41916359 0.52213612]
# Running param set  16 [0.58218586 0.31879275]
# Running param set  17 [0.59284643 0.04202515]
# Running param set  18 [0.25444635 0.12521294]
# Running param set  19 [0.05647785 0.46181587]
# Running param set  20 [0.68716252 0.35305047]
# Running param set  21 [0.05150198 0.64586496]
# Running param set  22 [0.9556052 0.8169672]
# Running param set  23 [0.85963924 0.71020653]
# Running param set  24 [0.21153341 0.57522447]
# Running param set  25 [0.41190171 0.68333801]
# Running param set  26 [0.46368299 0.9776369 ]
# Running param set  27 [0.06207734 0.12761274]
# Running param set  28 [0.28949548 0.78336703]
# Running param set  29 [0.36632254 0.50618468]
# Running param set  30 [0.729116   0.27411176]
# Running param set  31 [0.66674275 0.38328271]
# Running param set  32 [0.91835938 0.65694847]
# Running param set  33 [0.21764977 0.86705496]
# Running param set  34 [0.89777804 0.37646407]
# Running param set  35 [0.60638074 0.07117293]
# Running param set  36 [0.56207039 0.96397446]
# Running param set  37 [0.616943   0.76574076]
# Running param set  38 [0.60805316 0.37091023]
# Running param set  39 [0.23882431 0.48996655]
# Running param set  40 [0.28352526 0.11313894]
# Running param set  41 [0.45578752 0.85174966]
# Running param set  42 [0.36285462 0.62836418]
# Running param set  43 [0.01347691 0.15492578]
# Running param set  44 [0.92499339 0.30767716]
# Running param set  45 [0.66378485 0.35252486]
# Running param set  46 [0.96809443 0.45973447]
# Running param set  47 [0.0950306  0.27713847]
# Running param set  48 [0.03488759 0.43496643]
# Running param set  49 [0.20775738 0.67586291]
# Running param set  50 [0.07096101 0.76118102]
# Running param set  51 [0.26919248 0.9721016 ]
# Running param set  52 [0.99587479 0.79657588]
# Running param set  53 [0.78092793 0.31811537]
# Running param set  54 [0.20728738 0.5499048 ]
# Running param set  55 [0.65645595 0.07277057]
# Running param set  56 [0.94593614 0.47287749]
# Running param set  57 [0.84095768 0.88285964]
# Running param set  58 [0.73617246 0.53817755]
# Running param set  59 [0.23310316 0.49304895]
# Running param set  60 [0.7580558  0.36321105]
# Running param set  61 [0.30516698 0.20815439]
# Running param set  62 [0.95911927 0.69054345]
# Running param set  63 [0.49933286 0.75366522]
# Running param set  64 [0.50231375 0.43980408]
# Running param set  65 [0.73331092 0.13370924]
# Running param set  66 [0.60355511 0.11606846]
# Running param set  67 [0.71505089 0.87471295]
# Running param set  68 [0.23127705 0.94705687]
# Running param set  69 [0.8808692  0.72401391]
# Running param set  70 [0.97121589 0.30995535]
# Running param set  71 [0.72917674 0.05404997]
# Running param set  72 [0.56843885 0.25489354]
# Running param set  73 [0.31853045 0.24201783]
# Running param set  74 [0.5541243  0.58478274]
# Running param set  75 [0.76495455 0.68568084]
# Running param set  76 [0.49648958 0.5687566 ]
# Running param set  77 [0.50854169 0.79544604]
# Running param set  78 [0.6509674  0.64531854]
# Running param set  79 [0.04708013 0.84608139]
# Running param set  80 [0.53472865 0.51879044]
# Running param set  81 [0.89192647 0.44124275]
# Running param set  82 [0.18515214 0.14322539]
# Running param set  83 [0.44875142 0.31973077]
# Running param set  84 [0.46508236 0.40282752]
# Running param set  85 [0.54269533 0.83341305]
# Running param set  86 [0.39360114 0.0163348 ]
# Running param set  87 [0.64714284 0.1653758 ]
# Running param set  88 [0.84010493 0.88467158]
# Running param set  89 [0.99617166 0.76323385]
# Running param set  90 [0.57305627 0.04138058]
# Running param set  91 [0.75538631 0.36605586]
# Running param set  92 [0.42073704 0.81635505]
# Running param set  93 [0.0909614  0.25451633]
# Running param set  94 [0.65718263 0.30346374]
# Running param set  95 [0.45705401 0.41787493]
# Running param set  96 [0.02969066 0.33794225]
# Running param set  97 [0.9674177  0.51105759]
# Running param set  98 [0.52414911 0.96408329]
# Running param set  99 [0.30975361 0.17072351]
# Running param set  100 [0.92588822 0.61254347]
# Running param set  101 [0.93119928 0.89997859]
# Running param set  102 [0.01571953 0.17390509]
# Running param set  103 [0.70004962 0.70222784]
# Running param set  104 [0.67685033 0.43113175]
# Running param set  105 [0.64109421 0.84815089]
# Running param set  106 [0.09827592 0.60714538]
# Running param set  107 [0.66698887 0.44807803]
# Running param set  108 [0.29674184 0.21438067]
# Running param set  109 [0.95098083 0.03329144]
# Running param set  110 [0.05948869 0.12074886]
# Running param set  111 [0.28413921 0.60646065]
# Running param set  112 [0.32677531 0.58265457]
# Running param set  113 [0.2420195  0.30836819]
# Running param set  114 [0.54337677 0.11522789]
# Running param set  115 [0.50357167 0.65695969]
# Running param set  116 [0.09832388 0.29808982]
# Running param set  117 [0.76234976 0.13907607]
# Running param set  118 [0.7080402  0.16667583]
# Running param set  119 [0.17969643 0.96929825]
# Running param set  120 [0.25594644 0.43180348]
# Running param set  121 [0.04043502 0.45547491]
# Running param set  122 [0.58795687 0.47533684]
# Running param set  123 [0.36523792 0.31503605]
# Running param set  124 [0.30346441 0.60470498]
# Running param set  125 [0.73336799 0.8415979 ]
# Running param set  126 [0.76374742 0.46683019]
# Running param set  127 [0.98277792 0.18004692]
# Running param set  128 [0.10462272 0.47103967]
# Running param set  129 [0.07058543 0.87539148]
# Running param set  130 [0.89992281 0.22776973]
# Running param set  131 [0.38083235 0.75067528]
# Running param set  132 [0.95457775 0.12678601]
# Running param set  133 [0.54832751 0.74771807]
# Running param set  134 [0.60424635 0.46250189]
# Running param set  135 [0.96314494 0.07526561]
# Running param set  136 [0.20882129 0.64250292]
# Running param set  137 [0.67918568 0.07701743]
# Running param set  138 [0.98069533 0.51138459]
# Running param set  139 [0.11988335 0.37807209]
# Running param set  140 [0.35388045 0.10740703]
# Running param set  141 [0.71458003 0.5977561 ]
# Running param set  142 [0.41818486 0.65222961]
# Running param set  143 [0.31613029 0.57093693]
# Running param set  144 [0.07274772 0.99058507]
# Running param set  145 [0.76999938 0.04418426]
# Running param set  146 [0.63658146 0.28470442]
# Running param set  147 [0.96326812 0.58556929]
# Running param set  148 [0.83189622 0.53477334]
# Running param set  149 [0.67366846 0.65351815]
# Running param set  150 [0.18364949 0.89210839]
# Running param set  151 [0.24628909 0.98224173]
# Running param set  152 [0.28211801 0.97314597]
# Running param set  153 [0.49037397 0.85401744]
# Running param set  154 [0.25649262 0.5546624 ]
# Running param set  155 [0.38642421 0.07404042]
# Running param set  156 [0.49546802 0.95774833]
# Running param set  157 [0.64249553 0.73683666]
# Running param set  158 [0.07546482 0.67392298]
# Running param set  159 [0.48274127 0.55083276]
# Running param set  160 [0.324309   0.36355734]
# Running param set  161 [0.27957353 0.789595  ]
# Running param set  162 [0.14860716 0.23662826]
# Running param set  163 [0.3768041  0.32739545]
# Running param set  164 [0.36882628 0.3873173 ]
# Running param set  165 [0.16901459 0.5993362 ]
# Running param set  166 [0.19718172 0.4454183 ]
# Running param set  167 [0.62724393 0.48493021]
# Running param set  168 [0.3892569  0.80840718]
# Running param set  169 [0.20337909 0.02146039]
# Running param set  170 [0.37872016 0.60078722]
# Running param set  171 [0.06768519 0.22385755]
# Running param set  172 [0.57486209 0.86193023]
# Running param set  173 [0.28339222 0.32917625]
# Running param set  174 [0.75936948 0.54288525]
# Running param set  175 [0.78620637 0.12823529]
# Running param set  176 [0.25166073 0.24711388]
# Running param set  177 [0.16496242 0.32861815]
# Running param set  178 [0.06303696 0.34690372]
# Running param set  179 [0.0513163  0.06454786]
# Running param set  180 [0.60694244 0.04615247]
# Running param set  181 [0.9469117  0.77516961]
# Running param set  182 [0.00708181 0.07134072]
# Running param set  183 [0.89900455 0.05527336]
# Running param set  184 [0.04008335 0.9923612 ]
# Running param set  185 [0.45151295 0.00375606]
# Running param set  186 [0.34036194 0.67699526]
# Running param set  187 [0.12668236 0.71128425]
# Running param set  188 [0.07920619 0.69837925]
# Running param set  189 [0.13848282 0.53573484]
# Running param set  190 [0.87538579 0.34392581]
# Running param set  191 [0.43094734 0.55351805]
# Running param set  192 [0.68403531 0.99179757]
# Running param set  193 [0.32866034 0.26191728]
# Running param set  194 [0.93092404 0.9369621 ]
# Running param set  195 [0.00946207 0.40096894]
# Running param set  196 [0.67434044 0.82920329]
# Running param set  197 [0.50729966 0.89645393]
# Running param set  198 [0.25506252 0.5888898 ]
# Running param set  199 [0.08885121 0.40948369]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
