# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='case22'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return 0.1*((x-59)**3)+2

# %%
def get_data():
    n1=60
    n2=0.2
    m=36
    X=np.random.rand(n1)*10-5+59 #can change the distribution of X
    for j in range(1,m):
        B=59-np.random.rand(int(n2*(m-j)))*0.1*(m-j)
        X=np.hstack((X,B))
    Y=np.vectorize(actual_f)(X)
    for k in range(3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.30188928 0.23570733]
# Running param set  1 [0.98813532 0.09267713]
# Running param set  2 [0.68701655 0.73017792]
# Running param set  3 [0.76653813 0.83033637]
# Running param set  4 [0.99970537 0.56052251]
# Running param set  5 [0.37189308 0.35188961]
# Running param set  6 [0.79392173 0.5914897 ]
# Running param set  7 [0.7884291 0.2528868]
# Running param set  8 [0.10715744 0.33614411]
# Running param set  9 [0.7031651  0.74659932]
# Running param set  10 [0.96209836 0.13108992]
# Running param set  11 [0.3725165 0.8851347]
# Running param set  12 [0.71425133 0.30352334]
# Running param set  13 [0.38205043 0.10407708]
# Running param set  14 [0.90843036 0.74141554]
# Running param set  15 [0.55175376 0.95817226]
# Running param set  16 [0.93487648 0.74063859]
# Running param set  17 [0.11761478 0.50129774]
# Running param set  18 [0.78693841 0.89313306]
# Running param set  19 [0.00790936 0.81582056]
# Running param set  20 [0.90801112 0.51141844]
# Running param set  21 [0.08615912 0.29220073]
# Running param set  22 [0.66652827 0.65581716]
# Running param set  23 [0.27531635 0.41352014]
# Running param set  24 [0.61855209 0.10896882]
# Running param set  25 [0.09520707 0.35346457]
# Running param set  26 [0.49300284 0.88648212]
# Running param set  27 [0.74669166 0.85804389]
# Running param set  28 [0.5902003  0.09320511]
# Running param set  29 [0.12272952 0.69619812]
# Running param set  30 [0.51112879 0.24525786]
# Running param set  31 [0.79325942 0.79286488]
# Running param set  32 [0.16886182 0.23630723]
# Running param set  33 [0.15829693 0.68053135]
# Running param set  34 [0.37689518 0.19924206]
# Running param set  35 [0.73928237 0.94062201]
# Running param set  36 [0.58633172 0.46397522]
# Running param set  37 [0.50449139 0.94784623]
# Running param set  38 [0.32039309 0.08982773]
# Running param set  39 [0.96072584 0.88456542]
# Running param set  40 [0.6931595  0.61210039]
# Running param set  41 [0.64095834 0.05741177]
# Running param set  42 [0.23042604 0.85667025]
# Running param set  43 [0.29150713 0.28807825]
# Running param set  44 [0.22671033 0.99729872]
# Running param set  45 [0.88181923 0.53200234]
# Running param set  46 [0.42354592 0.85441969]
# Running param set  47 [0.3643234  0.84501033]
# Running param set  48 [0.6514642  0.14902495]
# Running param set  49 [0.05782915 0.37518786]
# Running param set  50 [0.33712702 0.24353749]
# Running param set  51 [0.98129482 0.23728591]
# Running param set  52 [0.47269626 0.0260684 ]
# Running param set  53 [0.38217227 0.52335944]
# Running param set  54 [0.08042652 0.07903275]
# Running param set  55 [0.19642697 0.60804647]
# Running param set  56 [0.79252624 0.80458703]
# Running param set  57 [0.81285878 0.45470324]
# Running param set  58 [0.19303266 0.13122177]
# Running param set  59 [0.89993316 0.72270315]
# Running param set  60 [0.21719194 0.81740367]
# Running param set  61 [0.57845716 0.81735142]
# Running param set  62 [0.31216386 0.36626133]
# Running param set  63 [0.23638314 0.94352794]
# Running param set  64 [0.31789391 0.39474417]
# Running param set  65 [0.98927469 0.68493289]
# Running param set  66 [0.99921667 0.65697023]
# Running param set  67 [0.47631273 0.30513928]
# Running param set  68 [0.72003595 0.93348377]
# Running param set  69 [0.32436013 0.69024491]
# Running param set  70 [0.0170877  0.08684181]
# Running param set  71 [0.34834707 0.29903482]
# Running param set  72 [0.05937395 0.74528363]
# Running param set  73 [0.45253677 0.04345812]
# Running param set  74 [0.08597252 0.30511839]
# Running param set  75 [0.32085978 0.41104419]
# Running param set  76 [0.00659102 0.84331895]
# Running param set  77 [0.46721741 0.54428008]
# Running param set  78 [0.08054284 0.64885892]
# Running param set  79 [0.37519439 0.94673367]
# Running param set  80 [0.47462036 0.03712721]
# Running param set  81 [0.10620675 0.70833443]
# Running param set  82 [0.68510501 0.12534598]
# Running param set  83 [0.48990476 0.69783379]
# Running param set  84 [0.7679949 0.8578849]
# Running param set  85 [0.11974811 0.92134141]
# Running param set  86 [0.01067849 0.29217849]
# Running param set  87 [0.87194164 0.47428198]
# Running param set  88 [0.41140407 0.60108452]
# Running param set  89 [0.53740322 0.37277513]
# Running param set  90 [0.27985555 0.34699491]
# Running param set  91 [0.84090047 0.28996758]
# Running param set  92 [0.10287545 0.92256955]
# Running param set  93 [0.72746049 0.88355787]
# Running param set  94 [0.9282946  0.02493543]
# Running param set  95 [0.60877507 0.71121981]
# Running param set  96 [0.80699163 0.17608297]
# Running param set  97 [0.74267034 0.89595814]
# Running param set  98 [0.27880679 0.52584272]
# Running param set  99 [0.16500542 0.38263724]
# Running param set  100 [0.22351926 0.12882229]
# Running param set  101 [0.89462174 0.48850688]
# Running param set  102 [0.73112789 0.24800654]
# Running param set  103 [0.8933566  0.16345818]
# Running param set  104 [0.33092067 0.91145741]
# Running param set  105 [0.86321151 0.16235559]
# Running param set  106 [0.11285519 0.33695972]
# Running param set  107 [0.0265065  0.03234555]
# Running param set  108 [0.66339937 0.38322852]
# Running param set  109 [0.23367197 0.80873559]
# Running param set  110 [0.41480506 0.31533661]
# Running param set  111 [0.73348342 0.93846821]
# Running param set  112 [0.58903533 0.15170606]
# Running param set  113 [0.09635147 0.03292307]
# Running param set  114 [0.22234443 0.85748282]
# Running param set  115 [0.19219677 0.90348176]
# Running param set  116 [0.58409697 0.9903357 ]
# Running param set  117 [0.77892351 0.70281128]
# Running param set  118 [0.02736232 0.52304262]
# Running param set  119 [0.2385588  0.01808347]
# Running param set  120 [0.34160325 0.72734829]
# Running param set  121 [0.0280622 0.6661003]
# Running param set  122 [0.23122995 0.42241883]
# Running param set  123 [0.58696068 0.44464392]
# Running param set  124 [0.53709134 0.53961043]
# Running param set  125 [0.06004043 0.01971309]
# Running param set  126 [0.88851719 0.38508993]
# Running param set  127 [0.09805011 0.36659367]
# Running param set  128 [0.68579006 0.90540064]
# Running param set  129 [0.40982888 0.64322413]
# Running param set  130 [0.61648777 0.86496619]
# Running param set  131 [0.35998557 0.20267883]
# Running param set  132 [0.14708259 0.16840493]
# Running param set  133 [0.15248017 0.51221517]
# Running param set  134 [0.73697589 0.6119681 ]
# Running param set  135 [0.09858921 0.77948507]
# Running param set  136 [0.7349236  0.19796054]
# Running param set  137 [0.40060226 0.84682026]
# Running param set  138 [0.84250045 0.47514453]
# Running param set  139 [0.61310919 0.47758978]
# Running param set  140 [0.47853614 0.066514  ]
# Running param set  141 [0.00145694 0.59988841]
# Running param set  142 [0.34506151 0.2162635 ]
# Running param set  143 [0.74897915 0.41831409]
# Running param set  144 [0.09345519 0.87093974]
# Running param set  145 [0.91868775 0.80798582]
# Running param set  146 [0.20117387 0.79933863]
# Running param set  147 [0.97362771 0.93155922]
# Running param set  148 [0.69563861 0.72513629]
# Running param set  149 [0.56635361 0.26266617]
# Running param set  150 [0.20652425 0.62545884]
# Running param set  151 [0.89208527 0.07134121]
# Running param set  152 [0.17419414 0.45688015]
# Running param set  153 [0.18173654 0.58896076]
# Running param set  154 [0.15769549 0.42797333]
# Running param set  155 [0.60614771 0.33052499]
# Running param set  156 [0.99460934 0.41927566]
# Running param set  157 [0.19413676 0.36279519]
# Running param set  158 [0.80531849 0.66716544]
# Running param set  159 [0.8465378  0.75290261]
# Running param set  160 [0.41740369 0.23859031]
# Running param set  161 [0.20886788 0.69149722]
# Running param set  162 [0.45186357 0.13888428]
# Running param set  163 [0.57990117 0.04091288]
# Running param set  164 [0.77738856 0.85424388]
# Running param set  165 [0.27444268 0.2220924 ]
# Running param set  166 [0.2747795  0.76354579]
# Running param set  167 [0.60801143 0.63763415]
# Running param set  168 [0.24486964 0.63288201]
# Running param set  169 [0.86739233 0.26942107]
# Running param set  170 [0.14505795 0.35327866]
# Running param set  171 [0.12589961 0.23258832]
# Running param set  172 [0.52100436 0.78376135]
# Running param set  173 [0.74219262 0.18419984]
# Running param set  174 [0.50487058 0.35150469]
# Running param set  175 [0.96590293 0.60803573]
# Running param set  176 [0.01570877 0.44232724]
# Running param set  177 [0.97621827 0.37758387]
# Running param set  178 [0.79887868 0.5065819 ]
# Running param set  179 [0.60250672 0.60692205]
# Running param set  180 [0.15486932 0.08629471]
# Running param set  181 [0.75942271 0.13518952]
# Running param set  182 [0.77827956 0.95856402]
# Running param set  183 [0.12396673 0.86402886]
# Running param set  184 [0.10224257 0.87708569]
# Running param set  185 [0.1882503  0.29775694]
# Running param set  186 [0.90963423 0.47423724]
# Running param set  187 [0.46967221 0.37832431]
# Running param set  188 [0.86410543 0.06244528]
# Running param set  189 [0.37591374 0.33013017]
# Running param set  190 [0.47936579 0.22272526]
# Running param set  191 [0.26607795 0.79205642]
# Running param set  192 [0.49474349 0.51364999]
# Running param set  193 [0.61298328 0.72668054]
# Running param set  194 [0.37885861 0.82577315]
# Running param set  195 [0.06829999 0.02342327]
# Running param set  196 [0.22336833 0.98181367]
# Running param set  197 [0.10925947 0.27259965]
# Running param set  198 [0.1375384 0.4038887]
# Running param set  199 [0.30826398 0.1279802 ]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
