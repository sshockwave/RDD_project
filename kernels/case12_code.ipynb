# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='case12'

# %%
def actual_f(x):
    return 0.1*((x-59)**3)+2

def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def get_data():
    n1=60
    n2=0.2
    m=18
    X=np.random.rand(n1)*10-5+59 #can change the distribution of X
    for i in range(1,m):
        A=59-np.random.rand(int(n2*(m-i)))*0.1*(m-i)
        X=np.hstack((X,A))
    for j in range(1,m):
        B=59-0.1*(m+j-1)-np.random.rand(int(n2*(m-j)))*0.1*(m-j)
        X=np.hstack((X,B))
    Y=np.vectorize(actual_f)(X)
    for k in range(3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.32874105 0.05966028]
# Running param set  1 [0.64393176 0.45619318]
# Running param set  2 [0.99833743 0.40600235]
# Running param set  3 [0.29382365 0.09854337]
# Running param set  4 [0.93624736 0.10082639]
# Running param set  5 [0.21689485 0.92723664]
# Running param set  6 [0.52681593 0.99486549]
# Running param set  7 [0.51473651 0.08408246]
# Running param set  8 [0.50130873 0.52916472]
# Running param set  9 [0.87614826 0.38612665]
# Running param set  10 [0.52008733 0.85241754]
# Running param set  11 [0.24366787 0.96660555]
# Running param set  12 [0.65295252 0.03360403]
# Running param set  13 [0.06423709 0.18040479]
# Running param set  14 [0.24238186 0.1723333 ]
# Running param set  15 [0.43537089 0.40082076]
# Running param set  16 [0.26061563 0.30044978]
# Running param set  17 [0.80377619 0.12750023]
# Running param set  18 [0.04055322 0.59990199]
# Running param set  19 [0.53480808 0.64650194]
# Running param set  20 [0.97191367 0.45329733]
# Running param set  21 [0.61501645 0.60837077]
# Running param set  22 [0.49779   0.9958987]
# Running param set  23 [0.55432093 0.71907214]
# Running param set  24 [0.94028863 0.21256597]
# Running param set  25 [0.62326216 0.76348353]
# Running param set  26 [0.55330166 0.27358824]
# Running param set  27 [0.47439116 0.86363995]
# Running param set  28 [0.47324629 0.06028527]
# Running param set  29 [0.35728648 0.47246751]
# Running param set  30 [0.20593033 0.17266948]
# Running param set  31 [0.30433658 0.89671747]
# Running param set  32 [0.29076262 0.72139191]
# Running param set  33 [0.68354384 0.08904777]
# Running param set  34 [0.40855822 0.48972905]
# Running param set  35 [0.67827388 0.31108179]
# Running param set  36 [0.81296347 0.88261615]
# Running param set  37 [0.63609078 0.88137143]
# Running param set  38 [0.15044279 0.96811095]
# Running param set  39 [0.87001891 0.51567672]
# Running param set  40 [0.34193075 0.42508963]
# Running param set  41 [0.86453254 0.54477443]
# Running param set  42 [0.3514465  0.99754734]
# Running param set  43 [0.39112641 0.63845265]
# Running param set  44 [0.81648477 0.83390888]
# Running param set  45 [0.74175652 0.81212372]
# Running param set  46 [0.291878   0.70175114]
# Running param set  47 [0.8367376  0.64292318]
# Running param set  48 [0.36689226 0.65831523]
# Running param set  49 [0.6617252  0.57930499]
# Running param set  50 [0.7122398  0.78678624]
# Running param set  51 [0.99145926 0.61417624]
# Running param set  52 [0.05263982 0.04496272]
# Running param set  53 [0.26007278 0.76893834]
# Running param set  54 [0.07957092 0.93546926]
# Running param set  55 [0.96634531 0.52202998]
# Running param set  56 [0.17093888 0.27033943]
# Running param set  57 [0.69715042 0.00311888]
# Running param set  58 [0.46768317 0.91106853]
# Running param set  59 [0.38195763 0.31623214]
# Running param set  60 [0.38369922 0.68866478]
# Running param set  61 [0.38896674 0.48163209]
# Running param set  62 [0.0840212 0.8889034]
# Running param set  63 [0.05158989 0.62525047]
# Running param set  64 [0.46433752 0.55237301]
# Running param set  65 [0.18268257 0.89579742]
# Running param set  66 [0.14635771 0.06913153]
# Running param set  67 [0.08970606 0.77281909]
# Running param set  68 [0.80307089 0.57619938]
# Running param set  69 [0.25452963 0.00878999]
# Running param set  70 [0.37873049 0.42719855]
# Running param set  71 [0.8593301  0.02364318]
# Running param set  72 [0.88358299 0.56991919]
# Running param set  73 [0.63076835 0.0764584 ]
# Running param set  74 [0.44053382 0.17483512]
# Running param set  75 [0.53423809 0.77828651]
# Running param set  76 [0.42064238 0.87195023]
# Running param set  77 [0.61585076 0.29434121]
# Running param set  78 [0.36973    0.14532171]
# Running param set  79 [0.90278843 0.98501463]
# Running param set  80 [0.924204   0.61035741]
# Running param set  81 [0.95702529 0.45714331]
# Running param set  82 [0.20233641 0.71754329]
# Running param set  83 [0.86894347 0.79284651]
# Running param set  84 [0.11184016 0.30808138]
# Running param set  85 [0.92084748 0.44281256]
# Running param set  86 [0.34013278 0.59375924]
# Running param set  87 [0.95866253 0.32555967]
# Running param set  88 [0.37549355 0.13619083]
# Running param set  89 [0.40662367 0.62916131]
# Running param set  90 [0.47612886 0.18407661]
# Running param set  91 [0.3189773  0.89949077]
# Running param set  92 [0.77901839 0.53100904]
# Running param set  93 [0.37753263 0.77476639]
# Running param set  94 [0.43897712 0.22227609]
# Running param set  95 [0.37221734 0.1145954 ]
# Running param set  96 [0.59109636 0.71898719]
# Running param set  97 [0.48041423 0.1185224 ]
# Running param set  98 [0.24648564 0.70842087]
# Running param set  99 [0.93646769 0.84878959]
# Running param set  100 [0.03320115 0.8791449 ]
# Running param set  101 [0.49878116 0.40851688]
# Running param set  102 [0.83373429 0.35670156]
# Running param set  103 [0.65317831 0.80395409]
# Running param set  104 [0.13676663 0.40651188]
# Running param set  105 [0.98211291 0.16432499]
# Running param set  106 [0.22463212 0.17696039]
# Running param set  107 [0.49675433 0.46303329]
# Running param set  108 [0.91796395 0.51172054]
# Running param set  109 [0.63571177 0.72719446]
# Running param set  110 [0.55193856 0.33205711]
# Running param set  111 [0.02521181 0.77634732]
# Running param set  112 [0.82493175 0.44147163]
# Running param set  113 [0.3867888  0.96423739]
# Running param set  114 [0.96760197 0.82525875]
# Running param set  115 [0.49822377 0.05317484]
# Running param set  116 [0.4606092 0.170168 ]
# Running param set  117 [0.02570237 0.68420441]
# Running param set  118 [0.73519324 0.61010064]
# Running param set  119 [0.40171366 0.12328694]
# Running param set  120 [0.34506417 0.24299282]
# Running param set  121 [0.64364007 0.1590659 ]
# Running param set  122 [0.98483906 0.4718932 ]
# Running param set  123 [0.90087278 0.61377291]
# Running param set  124 [0.39180759 0.81017733]
# Running param set  125 [0.97636133 0.53230506]
# Running param set  126 [0.70650036 0.42147235]
# Running param set  127 [0.96737961 0.37234982]
# Running param set  128 [0.60601476 0.5287885 ]
# Running param set  129 [0.20710439 0.1475576 ]
# Running param set  130 [0.40375243 0.59113357]
# Running param set  131 [0.61145986 0.03055448]
# Running param set  132 [0.89515348 0.75229064]
# Running param set  133 [0.34672874 0.13528963]
# Running param set  134 [0.46078914 0.50594138]
# Running param set  135 [0.13646821 0.35104953]
# Running param set  136 [0.88677664 0.03955267]
# Running param set  137 [0.27743287 0.69602346]
# Running param set  138 [0.82240515 0.06034365]
# Running param set  139 [0.31953157 0.68438129]
# Running param set  140 [0.83990454 0.68632052]
# Running param set  141 [0.42742819 0.92726055]
# Running param set  142 [0.64938585 0.95360486]
# Running param set  143 [0.74376422 0.73310816]
# Running param set  144 [0.18820176 0.59388304]
# Running param set  145 [0.16540202 0.18370385]
# Running param set  146 [0.72445888 0.12765101]
# Running param set  147 [0.56215475 0.38187499]
# Running param set  148 [0.89265304 0.74728543]
# Running param set  149 [0.43870811 0.96629675]
# Running param set  150 [0.1413079  0.56659004]
# Running param set  151 [0.77701208 0.11004711]
# Running param set  152 [0.20380798 0.62466554]
# Running param set  153 [0.58905174 0.31341182]
# Running param set  154 [0.10768187 0.82888729]
# Running param set  155 [0.84817502 0.25137503]
# Running param set  156 [0.62261068 0.87160217]
# Running param set  157 [0.82770046 0.6848875 ]
# Running param set  158 [0.2877518  0.33872269]
# Running param set  159 [0.4896148  0.70265139]
# Running param set  160 [0.919923   0.63304511]
# Running param set  161 [0.25840644 0.28367924]
# Running param set  162 [0.5992086  0.32657414]
# Running param set  163 [0.76862568 0.19977099]
# Running param set  164 [0.68014468 0.0305542 ]
# Running param set  165 [0.57585239 0.09242919]
# Running param set  166 [0.78506247 0.34656268]
# Running param set  167 [0.76886108 0.77613818]
# Running param set  168 [0.5362543  0.57853256]
# Running param set  169 [0.60385415 0.31314724]
# Running param set  170 [0.19564485 0.42687045]
# Running param set  171 [0.31216675 0.36080615]
# Running param set  172 [0.48466211 0.36130489]
# Running param set  173 [0.99733013 0.70282229]
# Running param set  174 [0.53885592 0.69244685]
# Running param set  175 [0.18278236 0.58010926]
# Running param set  176 [0.26892234 0.98091919]
# Running param set  177 [0.72696619 0.84956108]
# Running param set  178 [0.7722147 0.2305596]
# Running param set  179 [0.53624899 0.32957348]
# Running param set  180 [0.23422855 0.87524782]
# Running param set  181 [0.7241534  0.28718655]
# Running param set  182 [0.86786797 0.91068459]
# Running param set  183 [0.39462624 0.41902958]
# Running param set  184 [0.02142375 0.67884825]
# Running param set  185 [0.75127243 0.60342923]
# Running param set  186 [0.51836053 0.43567295]
# Running param set  187 [0.17681712 0.9121024 ]
# Running param set  188 [0.81245129 0.47460867]
# Running param set  189 [0.00961638 0.90778249]
# Running param set  190 [0.6937741  0.52774893]
# Running param set  191 [0.73217344 0.4670224 ]
# Running param set  192 [0.49227944 0.40718949]
# Running param set  193 [0.29902811 0.28617041]
# Running param set  194 [0.81887547 0.48228869]
# Running param set  195 [0.67442725 0.68784793]
# Running param set  196 [0.03630212 0.76913436]
# Running param set  197 [0.26998984 0.49448903]
# Running param set  198 [0.45394236 0.27983346]
# Running param set  199 [0.52060093 0.102554  ]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
