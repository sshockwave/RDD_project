# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='case32'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return 0.1*((x-59)**3)+2

# %%
def get_data():
    n1=60
    n2=0.2
    m=18
    X=np.random.rand(n1)*10-5+59 #can change the distribution of X
    for j in range(1,m):
        B=59-0.2*j-np.random.rand(int(n2*(m-j)))*0.2*(m-j)
        X=np.hstack((X,B))
    Y=np.vectorize(actual_f)(X)
    for k in range(3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.89477489 0.01829319]
# Running param set  1 [0.71445961 0.20611039]
# Running param set  2 [0.21993768 0.61054006]
# Running param set  3 [0.65405172 0.18885834]
# Running param set  4 [0.93079091 0.44984987]
# Running param set  5 [0.63110486 0.49445734]
# Running param set  6 [0.41087091 0.96935722]
# Running param set  7 [0.38846017 0.38966215]
# Running param set  8 [0.50784125 0.19237585]
# Running param set  9 [0.34180174 0.82818744]
# Running param set  10 [0.13478404 0.10182729]
# Running param set  11 [0.94997429 0.5060603 ]
# Running param set  12 [0.4848967  0.69025315]
# Running param set  13 [0.68827681 0.68992215]
# Running param set  14 [0.60666891 0.64479445]
# Running param set  15 [0.14284733 0.83877191]
# Running param set  16 [0.42644501 0.73794422]
# Running param set  17 [0.33682076 0.63099209]
# Running param set  18 [0.59619779 0.94503792]
# Running param set  19 [0.90768309 0.48984395]
# Running param set  20 [0.98198723 0.19992609]
# Running param set  21 [0.16345803 0.64851776]
# Running param set  22 [0.41492597 0.05227905]
# Running param set  23 [0.77491917 0.52998133]
# Running param set  24 [0.34563994 0.79471066]
# Running param set  25 [0.50054756 0.0511654 ]
# Running param set  26 [0.17035391 0.11446995]
# Running param set  27 [0.14643529 0.36953244]
# Running param set  28 [0.18652273 0.2543788 ]
# Running param set  29 [0.15053016 0.33172403]
# Running param set  30 [0.0009409  0.59196731]
# Running param set  31 [0.60020983 0.72297189]
# Running param set  32 [0.02061219 0.45812622]
# Running param set  33 [0.81729743 0.98439377]
# Running param set  34 [0.86517766 0.7621011 ]
# Running param set  35 [0.197138   0.84707386]
# Running param set  36 [0.13086231 0.67425592]
# Running param set  37 [0.44704459 0.18946884]
# Running param set  38 [0.85562722 0.56560705]
# Running param set  39 [0.79526359 0.75533419]
# Running param set  40 [0.79539043 0.57978483]
# Running param set  41 [0.13419851 0.73765912]
# Running param set  42 [0.05775206 0.47236378]
# Running param set  43 [0.26728746 0.4398067 ]
# Running param set  44 [0.36331583 0.03289373]
# Running param set  45 [0.74844208 0.37505067]
# Running param set  46 [0.53459145 0.00342705]
# Running param set  47 [0.82068022 0.10346927]
# Running param set  48 [0.5282581  0.00823449]
# Running param set  49 [0.40645336 0.49060756]
# Running param set  50 [0.97875067 0.53539894]
# Running param set  51 [0.3516521  0.96682695]
# Running param set  52 [0.05646961 0.77596702]
# Running param set  53 [0.51964218 0.686746  ]
# Running param set  54 [0.04637842 0.15842707]
# Running param set  55 [0.37552964 0.59236231]
# Running param set  56 [0.65456095 0.7855324 ]
# Running param set  57 [0.73590586 0.1292288 ]
# Running param set  58 [0.10280804 0.60049044]
# Running param set  59 [0.11113606 0.01363695]
# Running param set  60 [0.10357783 0.07687232]
# Running param set  61 [0.16236158 0.12124195]
# Running param set  62 [0.21248357 0.24450373]
# Running param set  63 [0.25591634 0.07845244]
# Running param set  64 [0.98227209 0.02139508]
# Running param set  65 [0.55446825 0.82825968]
# Running param set  66 [0.84247605 0.94712605]
# Running param set  67 [0.31433849 0.74106473]
# Running param set  68 [0.18361902 0.12360293]
# Running param set  69 [0.73415005 0.65669746]
# Running param set  70 [0.01457156 0.42940484]
# Running param set  71 [0.51666949 0.92474157]
# Running param set  72 [0.72781228 0.25692077]
# Running param set  73 [0.46956386 0.91001204]
# Running param set  74 [0.87315709 0.22747308]
# Running param set  75 [0.85527463 0.24015522]
# Running param set  76 [0.69289983 0.15780948]
# Running param set  77 [0.018358   0.99556389]
# Running param set  78 [0.3952482  0.65271464]
# Running param set  79 [0.10547961 0.74556184]
# Running param set  80 [0.2555645  0.23162464]
# Running param set  81 [0.9638334  0.32979287]
# Running param set  82 [0.9984779  0.13629968]
# Running param set  83 [0.045861   0.36269931]
# Running param set  84 [0.99144309 0.00618604]
# Running param set  85 [0.28472574 0.15591014]
# Running param set  86 [0.92010822 0.03057272]
# Running param set  87 [0.30610678 0.09469563]
# Running param set  88 [0.12708854 0.53587937]
# Running param set  89 [0.33716567 0.40973896]
# Running param set  90 [0.91764239 0.85498569]
# Running param set  91 [0.84339492 0.74627451]
# Running param set  92 [0.17066685 0.14420293]
# Running param set  93 [0.28469065 0.44420943]
# Running param set  94 [0.93258307 0.96233391]
# Running param set  95 [0.16735668 0.44579983]
# Running param set  96 [0.52751949 0.65120966]
# Running param set  97 [0.47946382 0.09099843]
# Running param set  98 [0.59664205 0.6831366 ]
# Running param set  99 [0.48944622 0.38257861]
# Running param set  100 [0.03661259 0.17918533]
# Running param set  101 [0.34268397 0.71529567]
# Running param set  102 [0.41251975 0.44951421]
# Running param set  103 [0.29273711 0.88289266]
# Running param set  104 [0.92298507 0.53286093]
# Running param set  105 [0.55590579 0.27215267]
# Running param set  106 [0.8557638 0.740874 ]
# Running param set  107 [0.38612932 0.68511764]
# Running param set  108 [0.67593303 0.19910981]
# Running param set  109 [0.53989456 0.50369005]
# Running param set  110 [0.99680825 0.82638058]
# Running param set  111 [0.32969778 0.08726124]
# Running param set  112 [0.96713361 0.72774394]
# Running param set  113 [0.13924169 0.38458141]
# Running param set  114 [0.03392817 0.48126675]
# Running param set  115 [0.17418346 0.48918773]
# Running param set  116 [0.54181243 0.86943083]
# Running param set  117 [0.0211824  0.36919524]
# Running param set  118 [0.23296372 0.19450218]
# Running param set  119 [0.91780315 0.20207553]
# Running param set  120 [0.68432141 0.00994273]
# Running param set  121 [0.84077784 0.02905155]
# Running param set  122 [0.02202373 0.96841205]
# Running param set  123 [0.68103419 0.91840997]
# Running param set  124 [0.01673849 0.3419687 ]
# Running param set  125 [0.82882625 0.79432045]
# Running param set  126 [0.14935638 0.85272852]
# Running param set  127 [0.47887699 0.08732732]
# Running param set  128 [0.10247654 0.34361455]
# Running param set  129 [0.24076724 0.51543003]
# Running param set  130 [0.01053363 0.52272335]
# Running param set  131 [0.371653   0.59031491]
# Running param set  132 [0.30894719 0.49455473]
# Running param set  133 [0.2871508  0.07021425]
# Running param set  134 [0.65542156 0.38311231]
# Running param set  135 [0.14884882 0.95281441]
# Running param set  136 [0.32173999 0.99749004]
# Running param set  137 [0.23208035 0.99297988]
# Running param set  138 [0.99794209 0.05331815]
# Running param set  139 [0.5387964 0.6107318]
# Running param set  140 [0.66710813 0.77077071]
# Running param set  141 [0.54763212 0.26388319]
# Running param set  142 [0.95223886 0.86574198]
# Running param set  143 [0.90273638 0.03857878]
# Running param set  144 [0.61038701 0.43889851]
# Running param set  145 [0.16748751 0.50636297]
# Running param set  146 [0.14542112 0.42725065]
# Running param set  147 [0.23220946 0.63415787]
# Running param set  148 [0.81298922 0.69712392]
# Running param set  149 [0.14379942 0.39873813]
# Running param set  150 [0.97680668 0.92489622]
# Running param set  151 [0.62170017 0.23906668]
# Running param set  152 [0.29457017 0.05027125]
# Running param set  153 [0.03078939 0.73795768]
# Running param set  154 [0.81923227 0.11085674]
# Running param set  155 [0.71082099 0.04726295]
# Running param set  156 [0.21612447 0.60312949]
# Running param set  157 [0.11990425 0.02056458]
# Running param set  158 [0.80508377 0.21209109]
# Running param set  159 [0.3294551  0.59711541]
# Running param set  160 [0.45532978 0.467917  ]
# Running param set  161 [0.5332984  0.02500465]
# Running param set  162 [0.94610893 0.51663373]
# Running param set  163 [0.80100796 0.47671688]
# Running param set  164 [0.85599017 0.81375982]
# Running param set  165 [0.46772351 0.12054591]
# Running param set  166 [0.88923353 0.81784634]
# Running param set  167 [0.40389594 0.40820381]
# Running param set  168 [0.22698363 0.26749303]
# Running param set  169 [0.23369535 0.02186793]
# Running param set  170 [0.26539144 0.82832237]
# Running param set  171 [0.73197097 0.71770219]
# Running param set  172 [0.29886201 0.23544142]
# Running param set  173 [0.93201377 0.05934742]
# Running param set  174 [0.83234868 0.34252559]
# Running param set  175 [0.45117757 0.86119021]
# Running param set  176 [0.86675062 0.83535697]
# Running param set  177 [0.86491954 0.6463729 ]
# Running param set  178 [0.85780973 0.71289738]
# Running param set  179 [0.05162377 0.32909159]
# Running param set  180 [0.66171156 0.05920714]
# Running param set  181 [0.80398206 0.08838169]
# Running param set  182 [0.61721853 0.6668462 ]
# Running param set  183 [0.38931518 0.22268651]
# Running param set  184 [0.59636528 0.3749843 ]
# Running param set  185 [0.21341075 0.71519602]
# Running param set  186 [0.96091465 0.03338689]
# Running param set  187 [0.80577569 0.30596277]
# Running param set  188 [0.63344557 0.82488094]
# Running param set  189 [0.54066956 0.11807478]
# Running param set  190 [0.96293854 0.39862586]
# Running param set  191 [0.71200865 0.97559264]
# Running param set  192 [0.70894005 0.6048801 ]
# Running param set  193 [0.5740832  0.83159968]
# Running param set  194 [0.42617453 0.33586626]
# Running param set  195 [0.96152844 0.762993  ]
# Running param set  196 [0.17865267 0.87702992]
# Running param set  197 [0.02543651 0.6087114 ]
# Running param set  198 [0.19104921 0.83831868]
# Running param set  199 [0.92855612 0.75630475]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
