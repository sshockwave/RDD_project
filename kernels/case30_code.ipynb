# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='case30'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return 0.2*((x-59)**2)+2

# %%
def get_data():
    n1=60
    n2=0.2
    m=18
    X=np.random.rand(n1)*10-5+59 #can change the distribution of X
    for j in range(1,m):
        B=59-0.2*j-np.random.rand(int(n2*(m-j)))*0.2*(m-j)
        X=np.hstack((X,B))
    Y=np.vectorize(actual_f)(X)
    for k in range(3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.72795169 0.11693862]
# Running param set  1 [0.51846404 0.89704705]
# Running param set  2 [0.75471988 0.30571852]
# Running param set  3 [0.75430359 0.58598184]
# Running param set  4 [0.82832195 0.4762979 ]
# Running param set  5 [0.9596685  0.47490838]
# Running param set  6 [0.48171877 0.53605838]
# Running param set  7 [0.14679954 0.28147979]
# Running param set  8 [0.39238865 0.67390291]
# Running param set  9 [0.68219937 0.33456643]
# Running param set  10 [0.86470494 0.79201113]
# Running param set  11 [0.2858211  0.82188674]
# Running param set  12 [0.54141528 0.39720337]
# Running param set  13 [0.94707054 0.4044925 ]
# Running param set  14 [0.50936002 0.07095892]
# Running param set  15 [0.1387477  0.80149228]
# Running param set  16 [0.51867667 0.30712296]
# Running param set  17 [0.02209448 0.71550925]
# Running param set  18 [0.2280869  0.81485553]
# Running param set  19 [0.6243115  0.60478788]
# Running param set  20 [0.05816178 0.01275332]
# Running param set  21 [0.82993144 0.108466  ]
# Running param set  22 [0.5880432  0.13525392]
# Running param set  23 [0.16180946 0.23024122]
# Running param set  24 [0.9950206  0.49845566]
# Running param set  25 [0.93417869 0.05671987]
# Running param set  26 [0.93139349 0.83544048]
# Running param set  27 [0.6033375  0.39565781]
# Running param set  28 [0.24182192 0.37420002]
# Running param set  29 [0.79771512 0.11144035]
# Running param set  30 [0.97261578 0.23730559]
# Running param set  31 [0.35930699 0.79049524]
# Running param set  32 [0.44797364 0.1400197 ]
# Running param set  33 [0.21300746 0.99217661]
# Running param set  34 [0.04690562 0.44124813]
# Running param set  35 [0.27614735 0.24723684]
# Running param set  36 [0.56650707 0.37652135]
# Running param set  37 [0.88311872 0.5425119 ]
# Running param set  38 [0.83540889 0.23178867]
# Running param set  39 [0.07213979 0.43070447]
# Running param set  40 [0.06158908 0.52349357]
# Running param set  41 [0.50523476 0.35792877]
# Running param set  42 [0.92976931 0.83596687]
# Running param set  43 [0.76337569 0.18453977]
# Running param set  44 [0.57925661 0.76531832]
# Running param set  45 [0.07648976 0.45822752]
# Running param set  46 [0.65519129 0.76151566]
# Running param set  47 [0.85272165 0.41679663]
# Running param set  48 [0.71329758 0.30346634]
# Running param set  49 [0.73240258 0.774445  ]
# Running param set  50 [0.11828009 0.65542163]
# Running param set  51 [0.49636872 0.43997757]
# Running param set  52 [0.1415904  0.99545884]
# Running param set  53 [0.70423935 0.71569647]
# Running param set  54 [0.73941614 0.97987138]
# Running param set  55 [0.77215805 0.68058949]
# Running param set  56 [0.18165863 0.0014458 ]
# Running param set  57 [0.45281711 0.51287747]
# Running param set  58 [0.97755928 0.7699876 ]
# Running param set  59 [0.25969462 0.66828685]
# Running param set  60 [0.46107983 0.62657229]
# Running param set  61 [0.72946075 0.72058585]
# Running param set  62 [0.90931399 0.20407891]
# Running param set  63 [0.971971   0.20956895]
# Running param set  64 [0.82651788 0.3940429 ]
# Running param set  65 [0.29985731 0.17160602]
# Running param set  66 [0.85463302 0.86044558]
# Running param set  67 [0.60904644 0.4585843 ]
# Running param set  68 [0.9730904  0.70910597]
# Running param set  69 [0.89777381 0.28193158]
# Running param set  70 [0.9785002  0.74594853]
# Running param set  71 [0.68832442 0.90078881]
# Running param set  72 [0.78790384 0.08704393]
# Running param set  73 [0.12096224 0.33012118]
# Running param set  74 [0.3683616  0.68087096]
# Running param set  75 [0.35888453 0.17420451]
# Running param set  76 [0.77215322 0.57624437]
# Running param set  77 [0.27685302 0.97851245]
# Running param set  78 [0.29360385 0.07235627]
# Running param set  79 [0.41130124 0.70292268]
# Running param set  80 [0.85921617 0.18406326]
# Running param set  81 [0.0955728  0.05312672]
# Running param set  82 [0.09824221 0.16373305]
# Running param set  83 [0.18895596 0.38366674]
# Running param set  84 [0.96300383 0.51822957]
# Running param set  85 [0.16781263 0.20168098]
# Running param set  86 [0.52428225 0.64090156]
# Running param set  87 [0.19847525 0.86456071]
# Running param set  88 [0.1565056  0.58499086]
# Running param set  89 [0.33134807 0.6517637 ]
# Running param set  90 [0.66866889 0.49069178]
# Running param set  91 [0.81191579 0.37990823]
# Running param set  92 [0.88672044 0.71287821]
# Running param set  93 [0.3262469 0.5693777]
# Running param set  94 [0.11238132 0.05583002]
# Running param set  95 [0.67737579 0.8041798 ]
# Running param set  96 [0.48354527 0.53478984]
# Running param set  97 [0.15141435 0.72653165]
# Running param set  98 [0.86824867 0.90594893]
# Running param set  99 [0.27140257 0.84095164]
# Running param set  100 [0.2190391 0.8843483]
# Running param set  101 [0.42504891 0.49605587]
# Running param set  102 [0.38246089 0.53486612]
# Running param set  103 [0.89060785 0.53423343]
# Running param set  104 [0.92056315 0.4078454 ]
# Running param set  105 [0.11292649 0.8428852 ]
# Running param set  106 [0.42596692 0.02925121]
# Running param set  107 [0.00519975 0.54411419]
# Running param set  108 [0.73648496 0.45189634]
# Running param set  109 [0.13884842 0.21882571]
# Running param set  110 [0.67153807 0.07967571]
# Running param set  111 [0.87534607 0.24902977]
# Running param set  112 [0.80082536 0.5564956 ]
# Running param set  113 [0.44270545 0.90900822]
# Running param set  114 [0.46466079 0.84423373]
# Running param set  115 [0.95291242 0.45019988]
# Running param set  116 [0.28653436 0.21775228]
# Running param set  117 [0.26137047 0.26001053]
# Running param set  118 [0.15955417 0.79665725]
# Running param set  119 [0.19088917 0.17420394]
# Running param set  120 [0.83929608 0.74172659]
# Running param set  121 [0.06207999 0.12391147]
# Running param set  122 [0.85993249 0.17457062]
# Running param set  123 [0.36140895 0.99547826]
# Running param set  124 [0.53319629 0.6869089 ]
# Running param set  125 [0.4025002  0.66342163]
# Running param set  126 [0.52432807 0.13776133]
# Running param set  127 [0.39308391 0.63990243]
# Running param set  128 [0.65399511 0.57973614]
# Running param set  129 [0.31440424 0.23474366]
# Running param set  130 [0.04450911 0.19426592]
# Running param set  131 [0.97167066 0.77639811]
# Running param set  132 [0.8828707  0.25728477]
# Running param set  133 [0.09591905 0.81421249]
# Running param set  134 [0.22781004 0.82727738]
# Running param set  135 [0.75241217 0.8187461 ]
# Running param set  136 [0.10515251 0.7923574 ]
# Running param set  137 [0.71868749 0.71397231]
# Running param set  138 [0.60641984 0.95417341]
# Running param set  139 [0.60758409 0.04810368]
# Running param set  140 [0.80921016 0.55043866]
# Running param set  141 [0.54436824 0.9455747 ]
# Running param set  142 [0.20086121 0.08688339]
# Running param set  143 [0.59418973 0.03662048]
# Running param set  144 [0.38328398 0.78558159]
# Running param set  145 [0.08817083 0.44171765]
# Running param set  146 [0.23126437 0.39779044]
# Running param set  147 [0.88432476 0.45695179]
# Running param set  148 [0.95946412 0.43011958]
# Running param set  149 [0.55163958 0.81359816]
# Running param set  150 [0.06585172 0.3951618 ]
# Running param set  151 [0.44483651 0.84120293]
# Running param set  152 [0.89223339 0.20072091]
# Running param set  153 [0.13016877 0.95541028]
# Running param set  154 [0.47555265 0.00326723]
# Running param set  155 [0.92059841 0.97739292]
# Running param set  156 [0.19959491 0.186767  ]
# Running param set  157 [0.78870562 0.90762286]
# Running param set  158 [0.74916939 0.16031679]
# Running param set  159 [0.1950416  0.29721216]
# Running param set  160 [0.74400729 0.72475148]
# Running param set  161 [0.93731232 0.05250562]
# Running param set  162 [0.88885167 0.34155689]
# Running param set  163 [0.85703111 0.89349346]
# Running param set  164 [0.62285361 0.52571591]
# Running param set  165 [0.44878059 0.0160028 ]
# Running param set  166 [0.58440789 0.0303233 ]
# Running param set  167 [0.58844074 0.82068314]
# Running param set  168 [0.47742615 0.22809118]
# Running param set  169 [0.2715258 0.6155346]
# Running param set  170 [0.53537334 0.63302653]
# Running param set  171 [0.76121119 0.53469138]
# Running param set  172 [0.26810723 0.91395684]
# Running param set  173 [0.93746118 0.8692559 ]
# Running param set  174 [0.78157449 0.68929871]
# Running param set  175 [0.26636178 0.62984563]
# Running param set  176 [0.87331013 0.13113707]
# Running param set  177 [0.70245294 0.77887805]
# Running param set  178 [0.78222976 0.59722676]
# Running param set  179 [0.19154373 0.22597624]
# Running param set  180 [0.6617868  0.95957933]
# Running param set  181 [0.18481854 0.6790247 ]
# Running param set  182 [0.67203619 0.55664099]
# Running param set  183 [0.68581299 0.02499623]
# Running param set  184 [0.15095331 0.40832875]
# Running param set  185 [0.41655369 0.64112611]
# Running param set  186 [0.21330425 0.01251294]
# Running param set  187 [0.71821994 0.07926212]
# Running param set  188 [0.48220353 0.6801621 ]
# Running param set  189 [0.32883776 0.75845027]
# Running param set  190 [0.29306427 0.99927741]
# Running param set  191 [0.64767799 0.97574694]
# Running param set  192 [0.95734407 0.33785794]
# Running param set  193 [0.84157519 0.72188747]
# Running param set  194 [0.94696884 0.86374588]
# Running param set  195 [0.85825822 0.28961502]
# Running param set  196 [0.4724622  0.84549218]
# Running param set  197 [0.14796018 0.68519897]
# Running param set  198 [0.91152231 0.44016318]
# Running param set  199 [0.42194174 0.09785774]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
