# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='casesz01'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return -0.2*((x-59)**2)-0.4*(x-59)+2

# %%
def get_data():
    n1=100
    Z=np.random.rand(n1)*2-1
    X=np.random.rand(n1)*10-5+59+Z
    Y=np.vectorize(actual_f)(X)+0.3*Z
    for k in range(0,3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.52219411 0.48650712]
# Running param set  1 [0.08479631 0.36267374]
# Running param set  2 [0.27215426 0.20386439]
# Running param set  3 [0.85299724 0.97073269]
# Running param set  4 [0.35835857 0.76302703]
# Running param set  5 [0.47728326 0.28908684]
# Running param set  6 [0.03608181 0.80314269]
# Running param set  7 [0.91954082 0.35276579]
# Running param set  8 [0.98003866 0.2257563 ]
# Running param set  9 [0.27896585 0.40490248]
# Running param set  10 [0.16321138 0.1440818 ]
# Running param set  11 [0.11322934 0.95273575]
# Running param set  12 [0.55873893 0.59564144]
# Running param set  13 [0.83931839 0.24434656]
# Running param set  14 [0.37648001 0.35901362]
# Running param set  15 [0.53352003 0.80999005]
# Running param set  16 [0.98568579 0.13286506]
# Running param set  17 [0.9678815  0.01429206]
# Running param set  18 [0.39941202 0.82394859]
# Running param set  19 [0.8950956  0.46129796]
# Running param set  20 [0.56706999 0.38129613]
# Running param set  21 [0.21044656 0.28128113]
# Running param set  22 [0.16206124 0.85391174]
# Running param set  23 [0.34369108 0.84863875]
# Running param set  24 [0.94063743 0.41057381]
# Running param set  25 [0.62317385 0.72383387]
# Running param set  26 [0.94500867 0.93761658]
# Running param set  27 [0.67977424 0.35780931]
# Running param set  28 [0.77266037 0.9864202 ]
# Running param set  29 [0.13238544 0.68744382]
# Running param set  30 [0.81664121 0.19088638]
# Running param set  31 [0.75794601 0.60869681]
# Running param set  32 [0.20037856 0.80452275]
# Running param set  33 [0.87296351 0.32911285]
# Running param set  34 [0.25389368 0.95682487]
# Running param set  35 [0.29698576 0.6653766 ]
# Running param set  36 [0.06019189 0.0811447 ]
# Running param set  37 [0.26744682 0.95248658]
# Running param set  38 [0.58818749 0.92088598]
# Running param set  39 [0.59052838 0.96644449]
# Running param set  40 [0.66084756 0.90168948]
# Running param set  41 [0.87382297 0.35761882]
# Running param set  42 [0.172998   0.41172621]
# Running param set  43 [0.39932836 0.11777367]
# Running param set  44 [0.89934722 0.80276828]
# Running param set  45 [0.24616508 0.15580165]
# Running param set  46 [0.34113139 0.28908952]
# Running param set  47 [0.33781183 0.61226483]
# Running param set  48 [0.77159018 0.88817076]
# Running param set  49 [0.12080044 0.97591357]
# Running param set  50 [0.30766651 0.98797667]
# Running param set  51 [0.08847985 0.70964903]
# Running param set  52 [0.45849346 0.39370396]
# Running param set  53 [0.66167954 0.26190339]
# Running param set  54 [0.0573316  0.68375426]
# Running param set  55 [0.56014912 0.07390792]
# Running param set  56 [0.21964388 0.96005865]
# Running param set  57 [0.44460835 0.61161157]
# Running param set  58 [0.45190981 0.61232398]
# Running param set  59 [0.48357631 0.68696562]
# Running param set  60 [0.68566325 0.71032   ]
# Running param set  61 [0.49203669 0.24552124]
# Running param set  62 [0.15730102 0.14138764]
# Running param set  63 [0.43126208 0.01927945]
# Running param set  64 [0.10461946 0.62555825]
# Running param set  65 [0.25888664 0.03526008]
# Running param set  66 [0.65122618 0.79017916]
# Running param set  67 [0.99587079 0.13869244]
# Running param set  68 [0.55422536 0.38998718]
# Running param set  69 [0.85411643 0.78348453]
# Running param set  70 [0.63323912 0.22682655]
# Running param set  71 [0.77602505 0.55410987]
# Running param set  72 [0.65339085 0.04676902]
# Running param set  73 [0.92562171 0.61423563]
# Running param set  74 [0.96217942 0.97650872]
# Running param set  75 [0.78519742 0.84073977]
# Running param set  76 [0.08546945 0.56864677]
# Running param set  77 [0.88256806 0.31389984]
# Running param set  78 [0.20508488 0.70663951]
# Running param set  79 [0.59639718 0.26239348]
# Running param set  80 [0.73880078 0.41601529]
# Running param set  81 [0.86190506 0.12685641]
# Running param set  82 [0.78296208 0.73630658]
# Running param set  83 [0.33225436 0.15450849]
# Running param set  84 [0.99438916 0.51320709]
# Running param set  85 [0.68814178 0.16777686]
# Running param set  86 [0.72248091 0.0913203 ]
# Running param set  87 [0.2563311  0.57932508]
# Running param set  88 [0.4055346  0.94928691]
# Running param set  89 [0.34957231 0.35115678]
# Running param set  90 [0.55572699 0.0734403 ]
# Running param set  91 [0.87161141 0.98614736]
# Running param set  92 [0.69117832 0.87082883]
# Running param set  93 [0.19272875 0.96178077]
# Running param set  94 [0.60665794 0.82202901]
# Running param set  95 [0.8180342  0.36523692]
# Running param set  96 [0.66491971 0.16398628]
# Running param set  97 [0.80287414 0.55611866]
# Running param set  98 [0.23780982 0.20987138]
# Running param set  99 [0.78313778 0.70364445]
# Running param set  100 [0.4398108  0.57704494]
# Running param set  101 [0.59497584 0.74238659]
# Running param set  102 [0.17890084 0.55447525]
# Running param set  103 [0.94576667 0.780929  ]
# Running param set  104 [0.33561218 0.16707889]
# Running param set  105 [0.92159065 0.50570531]
# Running param set  106 [0.8368059  0.46337759]
# Running param set  107 [0.0229355 0.0762607]
# Running param set  108 [0.95158389 0.43210258]
# Running param set  109 [0.35052253 0.02517325]
# Running param set  110 [0.89476804 0.71050863]
# Running param set  111 [0.13347708 0.34970985]
# Running param set  112 [0.30479519 0.04743703]
# Running param set  113 [0.15639065 0.0191259 ]
# Running param set  114 [0.46057751 0.53292471]
# Running param set  115 [0.22379698 0.96012818]
# Running param set  116 [0.84061473 0.39074545]
# Running param set  117 [0.78746792 0.23491772]
# Running param set  118 [0.55874619 0.0685475 ]
# Running param set  119 [0.56288143 0.37296651]
# Running param set  120 [0.33512752 0.51616837]
# Running param set  121 [0.59357891 0.17275575]
# Running param set  122 [0.22821464 0.39891621]
# Running param set  123 [0.97433292 0.79257033]
# Running param set  124 [0.40104093 0.0718227 ]
# Running param set  125 [0.62713537 0.20664978]
# Running param set  126 [0.65008328 0.32387242]
# Running param set  127 [0.73819394 0.85946868]
# Running param set  128 [0.20146509 0.79052624]
# Running param set  129 [0.83715382 0.9043279 ]
# Running param set  130 [0.78623173 0.27853111]
# Running param set  131 [0.97700037 0.65282621]
# Running param set  132 [0.5219454  0.62600714]
# Running param set  133 [0.41145585 0.21741364]
# Running param set  134 [0.95823907 0.64074884]
# Running param set  135 [0.0397465  0.71858866]
# Running param set  136 [0.05098236 0.35554965]
# Running param set  137 [0.57969506 0.42986899]
# Running param set  138 [0.59141884 0.29633007]
# Running param set  139 [0.86972154 0.43932521]
# Running param set  140 [0.57550814 0.0919239 ]
# Running param set  141 [0.35358699 0.69367289]
# Running param set  142 [0.43572243 0.50003607]
# Running param set  143 [0.6899852  0.13701207]
# Running param set  144 [0.6921845  0.19014359]
# Running param set  145 [0.8170673  0.90771333]
# Running param set  146 [0.31267635 0.1778276 ]
# Running param set  147 [0.53314164 0.27501016]
# Running param set  148 [0.60567171 0.66184601]
# Running param set  149 [0.7099277  0.54651062]
# Running param set  150 [0.6171603  0.90476755]
# Running param set  151 [0.71361566 0.61710834]
# Running param set  152 [0.54872928 0.2824493 ]
# Running param set  153 [0.68247648 0.03844133]
# Running param set  154 [0.74674725 0.10915497]
# Running param set  155 [0.82834757 0.90201604]
# Running param set  156 [0.33900223 0.61347118]
# Running param set  157 [0.76238542 0.56316055]
# Running param set  158 [0.78416957 0.43533724]
# Running param set  159 [0.73503223 0.4400654 ]
# Running param set  160 [0.17535458 0.29113044]
# Running param set  161 [0.3629706  0.08395787]
# Running param set  162 [0.49706871 0.65515019]
# Running param set  163 [0.71569734 0.86293702]
# Running param set  164 [0.74733086 0.68009477]
# Running param set  165 [0.23048747 0.65237598]
# Running param set  166 [0.22514981 0.48638341]
# Running param set  167 [0.81842198 0.3713321 ]
# Running param set  168 [0.78988391 0.98233284]
# Running param set  169 [0.60218945 0.22926772]
# Running param set  170 [0.00431733 0.64784866]
# Running param set  171 [0.89848254 0.8178062 ]
# Running param set  172 [0.11161723 0.3117249 ]
# Running param set  173 [0.62476082 0.37814211]
# Running param set  174 [0.29380199 0.05758011]
# Running param set  175 [0.75257846 0.82590584]
# Running param set  176 [0.05861334 0.7439533 ]
# Running param set  177 [0.58659355 0.88896115]
# Running param set  178 [0.39007045 0.86506069]
# Running param set  179 [0.28458996 0.42469402]
# Running param set  180 [0.61564625 0.92078336]
# Running param set  181 [0.37008779 0.91645331]
# Running param set  182 [0.53178871 0.91842223]
# Running param set  183 [0.18935702 0.77575507]
# Running param set  184 [0.00076669 0.06956246]
# Running param set  185 [0.02651649 0.74453642]
# Running param set  186 [0.58667879 0.86485996]
# Running param set  187 [0.11478656 0.82143782]
# Running param set  188 [0.18732884 0.46637566]
# Running param set  189 [0.07371878 0.20370751]
# Running param set  190 [0.17539801 0.16009877]
# Running param set  191 [0.1067137  0.12186368]
# Running param set  192 [0.97192146 0.80409389]
# Running param set  193 [0.35408045 0.53544545]
# Running param set  194 [0.25855463 0.2254914 ]
# Running param set  195 [0.99691494 0.07380412]
# Running param set  196 [0.07232776 0.23412298]
# Running param set  197 [0.34497085 0.6022459 ]
# Running param set  198 [0.82263417 0.26022911]
# Running param set  199 [0.9240048  0.90120116]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
