# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='casesz00'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return 0.2*((x-59)**2)+2

# %%
def get_data():
    n1=100
    Z=np.random.rand(n1)*2-1
    X=np.random.rand(n1)*10-5+59+Z
    Y=np.vectorize(actual_f)(X)+0.3*Z
    for k in range(0,3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [4.11737831e-04 8.22714923e-01]
# Running param set  1 [0.78942079 0.28824781]
# Running param set  2 [0.44364539 0.38921376]
# Running param set  3 [0.67187449 0.87990088]
# Running param set  4 [0.74160245 0.99136731]
# Running param set  5 [0.0494023  0.94473007]
# Running param set  6 [0.13948974 0.07396287]
# Running param set  7 [0.09629428 0.30066151]
# Running param set  8 [0.1224327  0.50604456]
# Running param set  9 [0.53332025 0.23794794]
# Running param set  10 [0.29894263 0.64579961]
# Running param set  11 [0.81623305 0.07537017]
# Running param set  12 [0.08678184 0.69313358]
# Running param set  13 [0.98883171 0.72960266]
# Running param set  14 [0.43679151 0.12922334]
# Running param set  15 [0.09774055 0.76693017]
# Running param set  16 [0.56234759 0.19648455]
# Running param set  17 [0.99010211 0.59829987]
# Running param set  18 [0.80304002 0.27935937]
# Running param set  19 [0.80938453 0.07490447]
# Running param set  20 [0.79218648 0.99791089]
# Running param set  21 [0.12133817 0.21702136]
# Running param set  22 [0.51356964 0.58846665]
# Running param set  23 [0.49448646 0.10736442]
# Running param set  24 [0.90423537 0.93543759]
# Running param set  25 [0.01709557 0.45350032]
# Running param set  26 [0.32638163 0.18674776]
# Running param set  27 [0.75935286 0.90240238]
# Running param set  28 [0.3945845  0.56788135]
# Running param set  29 [0.3712187  0.26450173]
# Running param set  30 [0.67883565 0.5098986 ]
# Running param set  31 [0.56178157 0.53289073]
# Running param set  32 [0.15301701 0.21197876]
# Running param set  33 [0.13937028 0.42358497]
# Running param set  34 [0.94544723 0.98816974]
# Running param set  35 [0.69446467 0.86630436]
# Running param set  36 [0.98269059 0.9220133 ]
# Running param set  37 [0.15398178 0.05409782]
# Running param set  38 [0.3980823  0.67455598]
# Running param set  39 [0.55513348 0.97863014]
# Running param set  40 [0.32869973 0.48498489]
# Running param set  41 [0.58867381 0.70950415]
# Running param set  42 [0.33139608 0.32392302]
# Running param set  43 [0.16214526 0.09893689]
# Running param set  44 [0.29757676 0.74313222]
# Running param set  45 [0.81935823 0.96138381]
# Running param set  46 [0.80486811 0.11430577]
# Running param set  47 [0.43832151 0.47197752]
# Running param set  48 [0.75364047 0.5142982 ]
# Running param set  49 [0.63325831 0.64899412]
# Running param set  50 [0.9932928  0.89151559]
# Running param set  51 [0.60049555 0.47783852]
# Running param set  52 [0.79196146 0.61355471]
# Running param set  53 [0.97646746 0.23584328]
# Running param set  54 [0.21820929 0.05155849]
# Running param set  55 [0.48705625 0.15759777]
# Running param set  56 [0.85032357 0.88602861]
# Running param set  57 [0.56064636 0.59648956]
# Running param set  58 [0.02837929 0.43420182]
# Running param set  59 [0.96014381 0.41189244]
# Running param set  60 [0.35028725 0.82750899]
# Running param set  61 [0.68729323 0.17202408]
# Running param set  62 [0.13401411 0.76560779]
# Running param set  63 [0.1492685  0.54763526]
# Running param set  64 [0.73428041 0.70551778]
# Running param set  65 [0.52797217 0.0306178 ]
# Running param set  66 [0.0814396  0.09697101]
# Running param set  67 [0.75295105 0.62774493]
# Running param set  68 [0.02772954 0.73293947]
# Running param set  69 [0.86715197 0.75560304]
# Running param set  70 [0.84909938 0.43268173]
# Running param set  71 [0.94162524 0.23724229]
# Running param set  72 [0.91547842 0.99421028]
# Running param set  73 [0.27366301 0.16742076]
# Running param set  74 [0.92213224 0.4256652 ]
# Running param set  75 [0.95291708 0.66029019]
# Running param set  76 [0.69201496 0.76948216]
# Running param set  77 [0.22486005 0.82361539]
# Running param set  78 [0.05250659 0.60175815]
# Running param set  79 [0.44508875 0.28471247]
# Running param set  80 [0.81924839 0.36518526]
# Running param set  81 [0.83050756 0.32854226]
# Running param set  82 [0.10455035 0.81589489]
# Running param set  83 [0.12833298 0.73712499]
# Running param set  84 [0.28336378 0.49421199]
# Running param set  85 [0.12490082 0.86482749]
# Running param set  86 [0.54546316 0.08799452]
# Running param set  87 [0.63352252 0.44773417]
# Running param set  88 [0.99813316 0.43139182]
# Running param set  89 [0.40055838 0.97227266]
# Running param set  90 [0.2274731 0.0797586]
# Running param set  91 [0.03763625 0.79282744]
# Running param set  92 [0.71412559 0.51548189]
# Running param set  93 [0.45634097 0.0492261 ]
# Running param set  94 [0.33902266 0.43652399]
# Running param set  95 [0.58192608 0.30877365]
# Running param set  96 [0.12631925 0.36477504]
# Running param set  97 [0.17716218 0.67400002]
# Running param set  98 [0.31071607 0.60744688]
# Running param set  99 [0.14767006 0.45644391]
# Running param set  100 [0.95382523 0.41493968]
# Running param set  101 [0.52730163 0.57571205]
# Running param set  102 [0.47189339 0.93126452]
# Running param set  103 [0.98375127 0.936868  ]
# Running param set  104 [0.90326645 0.80872109]
# Running param set  105 [0.62513227 0.34857082]
# Running param set  106 [0.6984608  0.20888262]
# Running param set  107 [0.70509616 0.03130815]
# Running param set  108 [0.48483211 0.7964778 ]
# Running param set  109 [0.32748892 0.33295557]
# Running param set  110 [0.6016474  0.59975019]
# Running param set  111 [0.41672701 0.86839751]
# Running param set  112 [0.15912552 0.44892316]
# Running param set  113 [0.72825916 0.05200315]
# Running param set  114 [0.97152468 0.41422116]
# Running param set  115 [0.99775487 0.50052165]
# Running param set  116 [0.93648865 0.11733488]
# Running param set  117 [0.79055952 0.99462397]
# Running param set  118 [0.03839881 0.56510484]
# Running param set  119 [0.63729099 0.37774622]
# Running param set  120 [0.93721776 0.76056322]
# Running param set  121 [0.68922266 0.31576932]
# Running param set  122 [0.70079524 0.76138358]
# Running param set  123 [0.04227835 0.84234902]
# Running param set  124 [0.78111585 0.35255038]
# Running param set  125 [0.54916333 0.76613949]
# Running param set  126 [0.75867711 0.44815094]
# Running param set  127 [0.44121049 0.40272137]
# Running param set  128 [0.6557822  0.08507392]
# Running param set  129 [0.19581762 0.5173281 ]
# Running param set  130 [0.31188481 0.68503909]
# Running param set  131 [0.00493629 0.24551177]
# Running param set  132 [0.12067069 0.86524772]
# Running param set  133 [0.64323625 0.8796755 ]
# Running param set  134 [0.50674655 0.02516178]
# Running param set  135 [0.53421015 0.27655849]
# Running param set  136 [0.04948722 0.08622954]
# Running param set  137 [0.94375484 0.09351023]
# Running param set  138 [0.51585502 0.27989497]
# Running param set  139 [0.71592398 0.51607485]
# Running param set  140 [0.55810419 0.71827666]
# Running param set  141 [0.64431242 0.94612062]
# Running param set  142 [0.76822766 0.5033463 ]
# Running param set  143 [0.63953272 0.49176336]
# Running param set  144 [0.89126157 0.46305158]
# Running param set  145 [0.91592224 0.79866002]
# Running param set  146 [0.67332748 0.59583998]
# Running param set  147 [0.08042245 0.14502681]
# Running param set  148 [0.23312276 0.88997533]
# Running param set  149 [0.11880257 0.19877143]
# Running param set  150 [0.49354355 0.13624128]
# Running param set  151 [0.47566448 0.03052544]
# Running param set  152 [0.91737458 0.89161672]
# Running param set  153 [0.97855692 0.60488024]
# Running param set  154 [0.66511216 0.77814002]
# Running param set  155 [0.36307676 0.69043724]
# Running param set  156 [0.56689002 0.84706739]
# Running param set  157 [0.93651458 0.00645753]
# Running param set  158 [0.98554357 0.19224816]
# Running param set  159 [0.67354553 0.27576754]
# Running param set  160 [0.33517678 0.92963009]
# Running param set  161 [0.40898701 0.89352038]
# Running param set  162 [0.4640485  0.63458522]
# Running param set  163 [0.23348133 0.14815142]
# Running param set  164 [0.41557097 0.28750073]
# Running param set  165 [0.86353234 0.06775067]
# Running param set  166 [0.0744524  0.26788849]
# Running param set  167 [0.93729665 0.63240272]
# Running param set  168 [0.72841843 0.58273164]
# Running param set  169 [0.65903721 0.49363909]
# Running param set  170 [0.65143542 0.89384535]
# Running param set  171 [0.92681841 0.09719077]
# Running param set  172 [0.95107486 0.83924133]
# Running param set  173 [0.64500063 0.12676214]
# Running param set  174 [0.58041478 0.29983822]
# Running param set  175 [0.14286692 0.08265464]
# Running param set  176 [0.80898271 0.99433345]
# Running param set  177 [0.44139963 0.11474885]
# Running param set  178 [0.94742142 0.16129013]
# Running param set  179 [0.92629097 0.80550456]
# Running param set  180 [0.53666832 0.96038059]
# Running param set  181 [0.68185965 0.62767016]
# Running param set  182 [0.33721031 0.46633669]
# Running param set  183 [0.33825436 0.93646139]
# Running param set  184 [0.88860069 0.86491963]
# Running param set  185 [0.98642269 0.08578793]
# Running param set  186 [0.23691084 0.66129952]
# Running param set  187 [0.56637349 0.07771912]
# Running param set  188 [0.59867274 0.0879125 ]
# Running param set  189 [0.63153985 0.14293511]
# Running param set  190 [0.03297741 0.15438519]
# Running param set  191 [0.75867739 0.52189427]
# Running param set  192 [0.16819339 0.6216759 ]
# Running param set  193 [0.12577227 0.535289  ]
# Running param set  194 [0.98086938 0.92848033]
# Running param set  195 [0.6522832  0.88699105]
# Running param set  196 [0.61024935 0.34163287]
# Running param set  197 [0.72708971 0.13057528]
# Running param set  198 [0.33674608 0.98088844]
# Running param set  199 [0.54953948 0.6065117 ]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
