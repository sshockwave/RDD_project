# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='casesz11'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return -0.2*((x-59)**2)-0.4*(x-59)+2

# %%
def get_data():
    n1=100
    Z=np.random.rand(n1)*2-1
    X=np.random.rand(n1)*10-5+59+Z**2
    Y=np.vectorize(actual_f)(X)+0.3*Z
    for k in range(0,3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.43008426 0.02208207]
# Running param set  1 [0.08492116 0.31019363]
# Running param set  2 [0.29023272 0.20989784]
# Running param set  3 [0.16278545 0.26525821]
# Running param set  4 [0.81680743 0.29988915]
# Running param set  5 [0.2643671  0.15917845]
# Running param set  6 [0.39292842 0.63461779]
# Running param set  7 [0.85982085 0.68120257]
# Running param set  8 [0.51085706 0.02656259]
# Running param set  9 [0.12927456 0.11154071]
# Running param set  10 [0.50359719 0.15382262]
# Running param set  11 [0.97070452 0.4012756 ]
# Running param set  12 [0.91464013 0.93642716]
# Running param set  13 [0.76242945 0.30012401]
# Running param set  14 [0.0746374  0.17832425]
# Running param set  15 [0.29499148 0.48196202]
# Running param set  16 [0.55016292 0.09714936]
# Running param set  17 [0.92891945 0.84155713]
# Running param set  18 [0.31448371 0.09258934]
# Running param set  19 [0.97075208 0.19463098]
# Running param set  20 [0.9917528  0.55206354]
# Running param set  21 [0.17101203 0.79830475]
# Running param set  22 [0.03931276 0.97633102]
# Running param set  23 [0.75602295 0.82891232]
# Running param set  24 [0.71086845 0.35867172]
# Running param set  25 [0.36270423 0.75909689]
# Running param set  26 [0.34018081 0.71732743]
# Running param set  27 [0.22548553 0.41350529]
# Running param set  28 [0.37281855 0.06702727]
# Running param set  29 [0.66545835 0.49049628]
# Running param set  30 [0.34965504 0.70382016]
# Running param set  31 [0.06590118 0.14070415]
# Running param set  32 [0.41963119 0.33682659]
# Running param set  33 [0.10216893 0.8628366 ]
# Running param set  34 [0.22857919 0.72368202]
# Running param set  35 [0.99929447 0.05975579]
# Running param set  36 [0.79463032 0.88430406]
# Running param set  37 [0.24867395 0.14502136]
# Running param set  38 [0.75047443 0.77353931]
# Running param set  39 [0.45962976 0.50109642]
# Running param set  40 [0.68681188 0.45134551]
# Running param set  41 [0.83579652 0.95757646]
# Running param set  42 [0.19678825 0.92131418]
# Running param set  43 [0.32182068 0.1667848 ]
# Running param set  44 [0.83616488 0.88752384]
# Running param set  45 [0.69971911 0.91941648]
# Running param set  46 [0.50429537 0.75140298]
# Running param set  47 [0.95267407 0.43025616]
# Running param set  48 [0.04819489 0.67171067]
# Running param set  49 [0.27781186 0.31213656]
# Running param set  50 [0.9264767  0.59828751]
# Running param set  51 [0.95166791 0.67900008]
# Running param set  52 [0.79802184 0.94500085]
# Running param set  53 [0.43720402 0.57570315]
# Running param set  54 [0.63830543 0.81759972]
# Running param set  55 [0.96424789 0.46206028]
# Running param set  56 [0.8810567 0.0535931]
# Running param set  57 [0.29945349 0.17384096]
# Running param set  58 [0.87394079 0.51528162]
# Running param set  59 [0.70332454 0.23691961]
# Running param set  60 [0.5112508 0.1377319]
# Running param set  61 [0.11766314 0.62106083]
# Running param set  62 [0.63682664 0.73986141]
# Running param set  63 [0.11299042 0.14016014]
# Running param set  64 [0.89098867 0.10770326]
# Running param set  65 [0.30978056 0.63650656]
# Running param set  66 [0.86881405 0.90076838]
# Running param set  67 [0.80623934 0.31564452]
# Running param set  68 [0.94705096 0.8680021 ]
# Running param set  69 [0.93165291 0.2791109 ]
# Running param set  70 [0.02630936 0.17692742]
# Running param set  71 [0.25067672 0.13288873]
# Running param set  72 [0.32913588 0.83574944]
# Running param set  73 [0.13087099 0.59413194]
# Running param set  74 [0.24234804 0.71845746]
# Running param set  75 [0.94538947 0.02407159]
# Running param set  76 [0.90825719 0.80386981]
# Running param set  77 [0.62924761 0.04591689]
# Running param set  78 [0.450554   0.36595348]
# Running param set  79 [0.14574937 0.43960163]
# Running param set  80 [0.74746991 0.79265685]
# Running param set  81 [0.20975749 0.71497289]
# Running param set  82 [0.93630836 0.22955804]
# Running param set  83 [0.00776143 0.12411769]
# Running param set  84 [0.65629216 0.14943779]
# Running param set  85 [0.08971004 0.15977803]
# Running param set  86 [0.26943061 0.24841454]
# Running param set  87 [0.73859751 0.11930062]
# Running param set  88 [0.648694   0.22455288]
# Running param set  89 [0.45536425 0.74706127]
# Running param set  90 [0.89489162 0.66320818]
# Running param set  91 [0.56129919 0.5480647 ]
# Running param set  92 [0.01162673 0.43846888]
# Running param set  93 [0.53645411 0.75711969]
# Running param set  94 [0.0557628  0.42860686]
# Running param set  95 [0.91252983 0.70679782]
# Running param set  96 [0.57729293 0.97903479]
# Running param set  97 [0.35536032 0.77615962]
# Running param set  98 [0.34161404 0.66985424]
# Running param set  99 [0.957578   0.68149164]
# Running param set  100 [0.79912544 0.65611478]
# Running param set  101 [0.63125801 0.93180596]
# Running param set  102 [0.90180868 0.0211345 ]
# Running param set  103 [0.92816539 0.7988675 ]
# Running param set  104 [0.92346374 0.30801253]
# Running param set  105 [0.11218735 0.20133276]
# Running param set  106 [0.87572965 0.65410706]
# Running param set  107 [0.64988525 0.83569845]
# Running param set  108 [0.79415054 0.84646037]
# Running param set  109 [0.95329772 0.75826852]
# Running param set  110 [0.49992348 0.11418612]
# Running param set  111 [0.01489646 0.12639211]
# Running param set  112 [0.28318082 0.43310147]
# Running param set  113 [0.3744536  0.02520515]
# Running param set  114 [0.31855159 0.86919303]
# Running param set  115 [0.06877461 0.19731206]
# Running param set  116 [0.20377766 0.43226915]
# Running param set  117 [0.81258965 0.95268283]
# Running param set  118 [0.90105636 0.22775926]
# Running param set  119 [0.87941198 0.9682542 ]
# Running param set  120 [0.92798649 0.85640672]
# Running param set  121 [0.77935633 0.94235051]
# Running param set  122 [0.76272358 0.00600939]
# Running param set  123 [0.16162873 0.57447647]
# Running param set  124 [0.81175475 0.37136847]
# Running param set  125 [0.71759444 0.74175008]
# Running param set  126 [0.89176462 0.5843334 ]
# Running param set  127 [0.29898882 0.85292319]
# Running param set  128 [0.26584267 0.31585246]
# Running param set  129 [0.29753762 0.10784296]
# Running param set  130 [0.9967459  0.89223821]
# Running param set  131 [0.40295256 0.08653211]
# Running param set  132 [0.43334015 0.6600081 ]
# Running param set  133 [0.03605402 0.48098479]
# Running param set  134 [0.53001402 0.06982125]
# Running param set  135 [0.32975277 0.90830306]
# Running param set  136 [0.93913294 0.62937656]
# Running param set  137 [0.70949151 0.91724966]
# Running param set  138 [0.26700039 0.59699332]
# Running param set  139 [0.79634501 0.5974923 ]
# Running param set  140 [0.46114351 0.01783357]
# Running param set  141 [0.18243925 0.04359156]
# Running param set  142 [0.58697049 0.35774676]
# Running param set  143 [0.30477958 0.41543955]
# Running param set  144 [0.25677413 0.11423085]
# Running param set  145 [0.84530139 0.16076155]
# Running param set  146 [0.40830982 0.11382045]
# Running param set  147 [0.0103934  0.06927977]
# Running param set  148 [0.47622399 0.4719912 ]
# Running param set  149 [0.09314291 0.64564527]
# Running param set  150 [0.36477766 0.41298258]
# Running param set  151 [0.00722333 0.74108168]
# Running param set  152 [0.07021099 0.36270263]
# Running param set  153 [0.29738321 0.29477357]
# Running param set  154 [0.96347021 0.16259457]
# Running param set  155 [0.23351682 0.32082069]
# Running param set  156 [0.30866441 0.76858484]
# Running param set  157 [0.48064101 0.41122405]
# Running param set  158 [0.30645486 0.45685033]
# Running param set  159 [0.90731124 0.29715171]
# Running param set  160 [0.01421148 0.33108764]
# Running param set  161 [0.48557939 0.36848974]
# Running param set  162 [0.41135923 0.32431885]
# Running param set  163 [0.95171484 0.68421342]
# Running param set  164 [0.36586232 0.70240685]
# Running param set  165 [0.35002811 0.11851561]
# Running param set  166 [0.16308745 0.72577666]
# Running param set  167 [0.18290266 0.46376576]
# Running param set  168 [0.68540447 0.54964306]
# Running param set  169 [0.08849717 0.52924927]
# Running param set  170 [0.75435796 0.74613234]
# Running param set  171 [0.99692804 0.25062909]
# Running param set  172 [0.95748867 0.50783398]
# Running param set  173 [0.71812411 0.30719593]
# Running param set  174 [0.7947348  0.11754173]
# Running param set  175 [0.97239653 0.43575978]
# Running param set  176 [0.06941927 0.09801633]
# Running param set  177 [0.81422848 0.63039576]
# Running param set  178 [0.44184882 0.38101033]
# Running param set  179 [0.17948747 0.257511  ]
# Running param set  180 [0.31151698 0.90809445]
# Running param set  181 [0.38005971 0.64335973]
# Running param set  182 [0.58260527 0.48501144]
# Running param set  183 [0.5187335  0.61764978]
# Running param set  184 [0.84769483 0.76863178]
# Running param set  185 [0.72303734 0.51168925]
# Running param set  186 [0.12183975 0.81556046]
# Running param set  187 [0.41623685 0.36214985]
# Running param set  188 [0.27412728 0.87426154]
# Running param set  189 [0.68648566 0.38123658]
# Running param set  190 [0.61911016 0.2614186 ]
# Running param set  191 [0.81244014 0.82759761]
# Running param set  192 [0.16594349 0.38598983]
# Running param set  193 [0.18481559 0.1162648 ]
# Running param set  194 [0.65694514 0.55595316]
# Running param set  195 [0.7926757  0.35738739]
# Running param set  196 [0.78973678 0.24907552]
# Running param set  197 [0.79949953 0.66383177]
# Running param set  198 [0.62469693 0.87219603]
# Running param set  199 [0.26167214 0.8739868 ]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
