# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation,PillowWriter,HTMLWriter
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

case_name='casesz10'

# %%
def regr_sided(X,Y,t,k,b):
    # Dispose points outside bandwidth
    YL=Y[np.logical_and(t-b<X,X<t)]
    XL=X[np.logical_and(t-b<X,X<t)]
    
    # Calculate weights
    get_weight=np.vectorize(lambda x:k((np.abs((x-t)))/b))
    WL=get_weight(XL)

    # Reshape for lib use
    # Every data has a single feature
    XL=XL.reshape(-1,1)
    YL=YL.reshape(-1,1)
    
    # Create linear regression object
    regrL = linear_model.LinearRegression()
    
    # Train the model using the training sets
    regrL.fit(XL, YL, sample_weight=WL)
    
    return regrL


def bias(X,Y,t,k,i):
    final_regr=regr_sided(X,Y,t,k,i)
    true_err=(final_regr.predict([[t]])[0][0]-actual_f(t))**2
    return true_err

# %%
def actual_f(x):
    return 0.2*((x-59)**2)+2

# %%
def get_data():
    n1=100
    Z=np.random.rand(n1)*2-1
    X=np.random.rand(n1)*10-5+59+Z**2
    Y=np.vectorize(actual_f)(X)+0.3*Z
    for k in range(0,3):
        Y=Y+0.6*np.random.rand(np.size(X))
    Y=Y-0.9
    Y=Y[np.logical_and(59-2.8**1.5<X,X<59)]
    X=X[np.logical_and(59-2.8**1.5<X,X<59)]
    return (X,Y)

# %%
testset=[]
for i in range(500):
    v=get_data()
    testset.append(v)
    X,Y=v
    plt.scatter(X,Y,s=0.001,color='red')
plt.show()

# %%
def repeat_test(t,k,b):
    errsum=0
    cnt=0
    for (X,Y) in testset:
        errsum+=bias(X,Y,t,k,b)
        cnt+=1
    return errsum/cnt

# %%
def bezier(p,t):
    # See https://javascript.info/bezier-curve
    if len(p)==1:
        return p[0]
    p2=[]
    for i in range(len(p)-1):
        p2.append((1-t)*p[i]+t*p[i+1])
    return bezier(p2,t)

# %%
def gen_param():
    p=np.array([1,np.random.rand(1)[0],np.random.rand(1)[0],0])
    return [lambda x:bezier(p,x),p]

# %%
t=59
ker_cnt=200
band_steps=50
kb=np.zeros((ker_cnt,band_steps))
param_set=[]
for i in range(ker_cnt):
    g=gen_param()
    param_set.append(g)
    print('Running param set ',i,g[1][1:3])
    k=0
    for j in np.exp(np.linspace(-0.3,1.2,band_steps)):
        b=repeat_test(t,g[0],j)
        kb[i][k]=b
        k=k+1
# Out:
# Running param set  0 [0.052593   0.83225401]
# Running param set  1 [0.38654337 0.65354537]
# Running param set  2 [0.00276438 0.30262215]
# Running param set  3 [0.6393054  0.48354094]
# Running param set  4 [0.57994885 0.64935929]
# Running param set  5 [0.43378628 0.24887521]
# Running param set  6 [0.08028036 0.87301649]
# Running param set  7 [0.84754296 0.7943283 ]
# Running param set  8 [0.44450816 0.32412861]
# Running param set  9 [0.14411645 0.88439332]
# Running param set  10 [0.42677871 0.66582698]
# Running param set  11 [0.12530797 0.69993784]
# Running param set  12 [0.40733574 0.03267254]
# Running param set  13 [0.53082341 0.66570679]
# Running param set  14 [0.96316193 0.40924189]
# Running param set  15 [0.62663047 0.09628711]
# Running param set  16 [0.46860022 0.0577816 ]
# Running param set  17 [0.93900015 0.99360673]
# Running param set  18 [0.80498937 0.01557603]
# Running param set  19 [0.49328606 0.56916992]
# Running param set  20 [0.58288093 0.93111282]
# Running param set  21 [0.35820159 0.81124122]
# Running param set  22 [0.81868917 0.49520936]
# Running param set  23 [0.16748117 0.77952658]
# Running param set  24 [0.22620301 0.29043382]
# Running param set  25 [0.74979388 0.37924345]
# Running param set  26 [0.4147389  0.19234199]
# Running param set  27 [0.08690262 0.40962578]
# Running param set  28 [0.51694307 0.71815336]
# Running param set  29 [0.3845041 0.3056361]
# Running param set  30 [0.57590119 0.36653244]
# Running param set  31 [0.47754017 0.93089414]
# Running param set  32 [0.47650466 0.1401169 ]
# Running param set  33 [0.25806023 0.24112761]
# Running param set  34 [0.59093581 0.51844263]
# Running param set  35 [0.59183795 0.30300296]
# Running param set  36 [0.61202735 0.50008383]
# Running param set  37 [0.97030742 0.85593994]
# Running param set  38 [0.5040436  0.29061135]
# Running param set  39 [0.64067083 0.12612076]
# Running param set  40 [0.01776021 0.10271001]
# Running param set  41 [0.88723971 0.24844755]
# Running param set  42 [0.96008454 0.87586263]
# Running param set  43 [0.994213   0.19164234]
# Running param set  44 [0.06259073 0.52871679]
# Running param set  45 [0.48946237 0.30137229]
# Running param set  46 [0.91257305 0.42452361]
# Running param set  47 [0.83261578 0.17978072]
# Running param set  48 [0.51755947 0.89837311]
# Running param set  49 [0.5925519  0.72324805]
# Running param set  50 [0.90811423 0.78744207]
# Running param set  51 [0.99793766 0.91389174]
# Running param set  52 [0.59215054 0.8864715 ]
# Running param set  53 [0.16984299 0.99535924]
# Running param set  54 [0.1491154  0.99466005]
# Running param set  55 [0.3535672  0.29415456]
# Running param set  56 [0.81821399 0.79001783]
# Running param set  57 [0.9165458  0.82286927]
# Running param set  58 [0.26478976 0.8492199 ]
# Running param set  59 [0.50438556 0.48334736]
# Running param set  60 [0.98128001 0.86172978]
# Running param set  61 [0.15806832 0.63898049]
# Running param set  62 [0.35873409 0.48180069]
# Running param set  63 [0.67697092 0.58661942]
# Running param set  64 [0.30574248 0.98015894]
# Running param set  65 [0.62514505 0.37841646]
# Running param set  66 [0.48407157 0.95626768]
# Running param set  67 [0.95442077 0.82404768]
# Running param set  68 [0.90564921 0.08733162]
# Running param set  69 [0.75609723 0.13671453]
# Running param set  70 [0.58813356 0.28199098]
# Running param set  71 [0.70479768 0.28611507]
# Running param set  72 [0.11092715 0.73392667]
# Running param set  73 [0.94000334 0.89382657]
# Running param set  74 [0.23257642 0.06548782]
# Running param set  75 [0.88052713 0.36656358]
# Running param set  76 [0.16400378 0.21858419]
# Running param set  77 [0.02387712 0.95462693]
# Running param set  78 [0.35392684 0.52424253]
# Running param set  79 [0.66720262 0.71100151]
# Running param set  80 [0.83571601 0.18957976]
# Running param set  81 [0.04784114 0.05054041]
# Running param set  82 [0.99194853 0.28110527]
# Running param set  83 [0.05013758 0.23087938]
# Running param set  84 [0.18893832 0.75289182]
# Running param set  85 [0.52398569 0.10426438]
# Running param set  86 [0.65783397 0.07477667]
# Running param set  87 [0.35205864 0.75000717]
# Running param set  88 [0.10344692 0.2781092 ]
# Running param set  89 [0.83052199 0.42329851]
# Running param set  90 [0.53685629 0.61895556]
# Running param set  91 [0.43456854 0.02981708]
# Running param set  92 [0.83073439 0.72087479]
# Running param set  93 [0.14054272 0.2036823 ]
# Running param set  94 [0.19743259 0.62496988]
# Running param set  95 [0.49004352 0.58162575]
# Running param set  96 [0.8877238  0.31966944]
# Running param set  97 [0.38471697 0.24967382]
# Running param set  98 [0.65555118 0.29189229]
# Running param set  99 [0.73860623 0.40311196]
# Running param set  100 [0.17694172 0.64749729]
# Running param set  101 [0.05446195 0.64406489]
# Running param set  102 [0.83271927 0.98845897]
# Running param set  103 [0.46284876 0.45193287]
# Running param set  104 [0.16546192 0.02389269]
# Running param set  105 [0.35485743 0.04627159]
# Running param set  106 [0.51176199 0.37580247]
# Running param set  107 [0.67034908 0.8860879 ]
# Running param set  108 [0.40478255 0.7525294 ]
# Running param set  109 [0.23828388 0.90111549]
# Running param set  110 [0.14026777 0.67906043]
# Running param set  111 [0.3227074  0.14351456]
# Running param set  112 [0.31943088 0.82513976]
# Running param set  113 [0.42561286 0.31448383]
# Running param set  114 [0.10113503 0.50505197]
# Running param set  115 [0.05714725 0.61959467]
# Running param set  116 [0.76778523 0.17476221]
# Running param set  117 [0.25391934 0.97256535]
# Running param set  118 [0.56568739 0.61564102]
# Running param set  119 [0.32794032 0.69476463]
# Running param set  120 [0.77199674 0.45294319]
# Running param set  121 [0.8670923  0.11483568]
# Running param set  122 [0.75727346 0.41310252]
# Running param set  123 [0.26883073 0.81058774]
# Running param set  124 [0.0061048  0.90016805]
# Running param set  125 [0.2425394  0.10088248]
# Running param set  126 [0.55227878 0.66778201]
# Running param set  127 [0.48878258 0.68562163]
# Running param set  128 [0.72897415 0.26127889]
# Running param set  129 [0.60424334 0.68588583]
# Running param set  130 [0.08446826 0.19862302]
# Running param set  131 [0.66000011 0.86452787]
# Running param set  132 [0.52259975 0.16129246]
# Running param set  133 [0.33263744 0.36810468]
# Running param set  134 [0.96330574 0.85650789]
# Running param set  135 [0.37054517 0.7193418 ]
# Running param set  136 [0.55876019 0.19865353]
# Running param set  137 [0.14769704 0.02246081]
# Running param set  138 [0.36142248 0.17533773]
# Running param set  139 [0.90465342 0.26630027]
# Running param set  140 [0.53642775 0.70774166]
# Running param set  141 [0.20944341 0.83328063]
# Running param set  142 [0.3789769  0.43305506]
# Running param set  143 [0.26869407 0.08675494]
# Running param set  144 [0.07811874 0.09962442]
# Running param set  145 [0.18924894 0.0967051 ]
# Running param set  146 [0.22197747 0.96986988]
# Running param set  147 [0.58599172 0.5083492 ]
# Running param set  148 [0.49294982 0.08465196]
# Running param set  149 [0.56729234 0.94425365]
# Running param set  150 [0.95868264 0.1742416 ]
# Running param set  151 [0.13211074 0.65522742]
# Running param set  152 [0.14232048 0.76126259]
# Running param set  153 [0.17152434 0.84251109]
# Running param set  154 [0.14115329 0.83949679]
# Running param set  155 [0.47272103 0.39409172]
# Running param set  156 [0.01570773 0.82968896]
# Running param set  157 [0.30971932 0.19516306]
# Running param set  158 [0.51738604 0.01002647]
# Running param set  159 [0.95083506 0.97821254]
# Running param set  160 [0.73504019 0.90040713]
# Running param set  161 [0.84398138 0.20633594]
# Running param set  162 [0.70214654 0.25027026]
# Running param set  163 [0.93288114 0.4366363 ]
# Running param set  164 [0.53255231 0.7899337 ]
# Running param set  165 [0.56531876 0.30689399]
# Running param set  166 [0.96221697 0.05878568]
# Running param set  167 [0.20702665 0.86129232]
# Running param set  168 [0.81353045 0.11675732]
# Running param set  169 [0.85292181 0.17460595]
# Running param set  170 [0.32641664 0.90233197]
# Running param set  171 [0.48876269 0.85414255]
# Running param set  172 [0.07163544 0.00144642]
# Running param set  173 [0.70149541 0.37922452]
# Running param set  174 [0.40986751 0.74168524]
# Running param set  175 [0.12037091 0.17959955]
# Running param set  176 [0.91341243 0.42881906]
# Running param set  177 [0.65660169 0.54657145]
# Running param set  178 [0.25621219 0.29364127]
# Running param set  179 [0.57044148 0.82583147]
# Running param set  180 [0.79350403 0.83400117]
# Running param set  181 [0.06357363 0.38646087]
# Running param set  182 [0.60938153 0.54303156]
# Running param set  183 [0.06205866 0.8475577 ]
# Running param set  184 [0.88339107 0.09004915]
# Running param set  185 [0.7590524  0.92688891]
# Running param set  186 [0.35569202 0.34674925]
# Running param set  187 [0.24967304 0.48464037]
# Running param set  188 [0.23304452 0.82851539]
# Running param set  189 [0.89616105 0.69870892]
# Running param set  190 [0.20130653 0.54927733]
# Running param set  191 [0.93529307 0.88175363]
# Running param set  192 [0.05133467 0.86666579]
# Running param set  193 [0.63484956 0.55142001]
# Running param set  194 [0.89452161 0.1354944 ]
# Running param set  195 [0.49604515 0.52785044]
# Running param set  196 [0.55444313 0.57489897]
# Running param set  197 [0.1309179  0.68768388]
# Running param set  198 [0.09631892 0.10655223]
# Running param set  199 [0.82234217 0.37356452]

# %%
f = open (case_name+'_outputbkt2.txt','w')
for param in param_set:
    print(i,param[1][1],param[1][2],file=f)
kerr=np.zeros(band_steps)+100
kbest=np.zeros(band_steps).astype(int)
for j in range(band_steps):
    for i in range(ker_cnt):
        if kerr[j]>kb[i][j]:
            kerr[j]=kb[i][j]
            kbest[j]=i
    print(kerr[j],kbest[j],file=f)

f.close()

# %%
fig, ax = plt.subplots()
curve, = plt.plot([],[],color='red')
line1, = plt.plot([],[],color='green')
line2, = plt.plot([],[],color='green')

def init():
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    return
band_set=np.exp(np.linspace(-0.3,1.2,band_steps))
def animate(j):
    ax.set_title('bandwidth='+str(band_set[j]))
    ker=param_set[kbest[j]][0]
    p=param_set[kbest[j]][1]
    X=np.linspace(0,1,100)
    curve.set_data(X,np.vectorize(ker)(X))
    line1.set_data([0.01,0.01],[p[0],p[1]])
    line2.set_data([0.99,0.99],[p[2],p[3]])
    return curve,line1,line2

ani = FuncAnimation(fig=fig, func=animate, frames=band_steps, init_func=init, interval=30, blit=False)
writer = PillowWriter()
ani.save(case_name+"_graph.gif", writer=writer)
hwriter = HTMLWriter(fps=5)
ani.save(case_name+'_graph.html',writer=hwriter)
